# %% [markdown]
# # Centers

# %% [markdown]
# ### Months Played (Regular Season - 17/18)

# %%
Month = ["October","November","December","January","February","March","April"]
MonthD = {"October":0,"November":1,"December":2,"January":3,"February":4,"March":5,"April":6}

# %% [markdown]
# ### Player List

# %%
Players = ["AndreDrummond", "DeMarcusCousins", "DwightHoward", "JoelEmbiid", "JusufNurkic", "KarlAnthonyTowns", "KevinLove", "MarcGasol", "NikolaJokic", "NikolaVucevic"]
PlayerD = {"AndreDrummond":0, "DeMarcusCousins":1, "DwightHoward":2, "JoelEmbiid":3, "JusufNurkic":4, "KarlAnthonyTowns":5, "KevinLove":6, "MarcGasol":7, "NikolaJokic":8, "NikolaVucevic":9}

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Importing the CSV File

# %%
center = pd.read_csv('C:\\Users\\Sarad\\Desktop\\Project\\Center.csv')

# %%
center
# Out:
#                 PLAYER TEAM  GP  MIN  PTS  FGM  FGA  FTM  FTA  REB  BLK  DD2
# 0       Andre Drummond  DET   8  263  100   43   84   14   20  113    8    5
# 1       Andre Drummond  DET  12  400  186   71  124   44   72  190   15    9
# 2       Andre Drummond  DET  15  482  213   82  158   49   79  227   20   11
# 3       Andre Drummond  DET  12  414  198   81  139   36   60  188   23    9
# 4       Andre Drummond  DET  12  404  196   79  161   38   58  212   26   12
# 5       Andre Drummond  DET  15  517  221   86  172   49   85  254   32   12
# 6       Andre Drummond  DET   4  146   57   24   43    9   21   63    3    4
# 7     DeMarcus Cousins  NOP   7  260  206   70  143   49   64   95   15    7
# 8     DeMarcus Cousins  NOP  14  485  321  112  251   68   90  167   18    9
# 9     DeMarcus Cousins  NOP  15  531  416  141  281  100  136  189   21   11
# 10    DeMarcus Cousins  NOP  12  460  267   83  189   77  104  166   22   11
# ...

# %% [markdown]
# ### Games

# %%
AndreDrummond_Games = list(center['GP'][0:7])
DeMarcusCousins_Games = list(center['GP'][7:14])
DwightHoward_Games = list(center['GP'][14:21])
JoelEmbiid_Games = list(center['GP'][21:28])
JusufNurkic_Games = list(center['GP'][28:35])
KarlAnthonyTowns_Games = list(center['GP'][35:42])
KevinLove_Games = list(center['GP'][42:49])
MarcGasol_Games = list(center['GP'][49:56])
NikolaJokic_Games = list(center['GP'][56:63])
NikolaVucevic_Games = list(center['GP'][63:71])

Games = np.array([AndreDrummond_Games, DeMarcusCousins_Games, DwightHoward_Games, JoelEmbiid_Games, JusufNurkic_Games, KarlAnthonyTowns_Games, KevinLove_Games, MarcGasol_Games, NikolaJokic_Games, NikolaVucevic_Games])

# %%
Games
# Out:
# array([[ 8, 12, 15, 12, 12, 15,  4],
#        [ 7, 14, 15, 12,  0,  0,  0],
#        [ 7, 13, 16, 14, 12, 14,  5],
#        [ 6, 12,  9, 11, 10, 15,  0],
#        [ 7, 15, 10, 16, 10, 15,  6],
#        [ 7, 15, 15, 17, 10, 13,  5],
#        [ 7, 15, 13, 13,  0,  6,  5],
#        [ 7, 13, 17, 12,  9, 12,  3],
#        [ 7, 14,  8, 15, 10, 15,  6],
#        [ 7, 15, 12,  0,  4, 14,  5]], dtype=int64)

# %% [markdown]
# ### Minutes Played

# %%
AndreDrummond_Minutes = list(center['MIN'][0:7])
DeMarcusCousins_Minutes = list(center['MIN'][7:14])
DwightHoward_Minutes = list(center['MIN'][14:21])
JoelEmbiid_Minutes = list(center['MIN'][21:28])
JusufNurkic_Minutes = list(center['MIN'][28:35])
KarlAnthonyTowns_Minutes = list(center['MIN'][35:42])
KevinLove_Minutes = list(center['MIN'][42:49])
MarcGasol_Minutes = list(center['MIN'][49:56])
NikolaJokic_Minutes = list(center['MIN'][56:63])
NikolaVucevic_Minutes = list(center['MIN'][63:71])

MinutesPlayed = np.array([AndreDrummond_Minutes, DeMarcusCousins_Minutes, DwightHoward_Minutes, JoelEmbiid_Minutes, JusufNurkic_Minutes, KarlAnthonyTowns_Minutes, KevinLove_Minutes, MarcGasol_Minutes, NikolaJokic_Minutes, NikolaVucevic_Minutes])

# %%
MinutesPlayed
# Out:
# array([[263, 400, 482, 414, 404, 517, 146],
#        [260, 485, 531, 460,   0,   0,   0],
#        [217, 377, 485, 469, 350, 427, 137],
#        [162, 370, 314, 356, 302, 408,   0],
#        [182, 438, 249, 406, 260, 379, 173],
#        [244, 511, 571, 579, 347, 482, 184],
#        [206, 445, 386, 306,   0, 148, 161],
#        [239, 448, 592, 398, 288, 368,  75],
#        [225, 393, 261, 508, 312, 507, 236],
#        [214, 441, 363,   0, 116, 434, 116]], dtype=int64)

# %% [markdown]
# ### Points

# %%
AndreDrummond_Points = list(center['PTS'][0:7])
DeMarcusCousins_Points = list(center['PTS'][7:14])
DwightHoward_Points = list(center['PTS'][14:21])
JoelEmbiid_Points = list(center['PTS'][21:28])
JusufNurkic_Points = list(center['PTS'][28:35])
KarlAnthonyTowns_Points = list(center['PTS'][35:42])
KevinLove_Points = list(center['PTS'][42:49])
MarcGasol_Points = list(center['PTS'][49:56])
NikolaJokic_Points = list(center['PTS'][56:63])
NikolaVucevic_Points = list(center['PTS'][63:71])


PointsMade = np.array([AndreDrummond_Points, DeMarcusCousins_Points, DwightHoward_Points, JoelEmbiid_Points, JusufNurkic_Points, KarlAnthonyTowns_Points, KevinLove_Points, MarcGasol_Points, NikolaJokic_Points, NikolaVucevic_Points])

# %%
PointsMade
# Out:
# array([[100, 186, 213, 198, 196, 221,  57],
#        [206, 321, 416, 267,   0,   0,   0],
#        [ 96, 215, 249, 238, 188, 288,  73],
#        [125, 288, 232, 259, 244, 297,   0],
#        [ 88, 252, 124, 218, 137, 229,  84],
#        [169, 280, 303, 317, 230, 334, 110],
#        [134, 283, 289, 151,   0,  90,  92],
#        [141, 231, 314, 195, 148, 202,  27],
#        [121, 204, 147, 241, 218, 300, 154],
#        [145, 217, 228,   0,  63, 236,  50]], dtype=int64)

# %% [markdown]
# ### Field Goals

# %%
AndreDrummond_FG = list(center['FGM'][0:7])
DeMarcusCousins_FG = list(center['FGM'][7:14])
DwightHoward_FG = list(center['FGM'][14:21])
JoelEmbiid_FG = list(center['FGM'][21:28])
JusufNurkic_FG = list(center['FGM'][28:35])
KarlAnthonyTowns_FG = list(center['FGM'][35:42])
KevinLove_FG = list(center['FGM'][42:49])
MarcGasol_FG = list(center['FGM'][49:56])
NikolaJokic_FG = list(center['FGM'][56:63])
NikolaVucevic_FG = list(center['FGM'][63:71])

FieldGoals = np.array([AndreDrummond_FG, DeMarcusCousins_FG, DwightHoward_FG, JoelEmbiid_FG, JusufNurkic_FG, KarlAnthonyTowns_FG, KevinLove_FG, MarcGasol_FG, NikolaJokic_FG, NikolaVucevic_FG])

# %%
FieldGoals
# Out:
# array([[ 43,  71,  82,  81,  79,  86,  24],
#        [ 70, 112, 141,  83,   0,   0,   0],
#        [ 38,  78,  88,  89,  81, 106,  26],
#        [ 47, 101,  74,  92,  91, 105,   0],
#        [ 32, 107,  48,  91,  61, 102,  39],
#        [ 65, 104, 109, 120,  79, 117,  45],
#        [ 40,  91,  98,  49,   0,  29,  27],
#        [ 44,  85, 107,  68,  49,  70,  11],
#        [ 46,  77,  52,  86,  74, 110,  59],
#        [ 61,  90,  97,   0,  27, 103,  21]], dtype=int64)

# %% [markdown]
# ### Field Goals Attempted

# %%
AndreDrummond_FGA = list(center['FGA'][0:7])
DeMarcusCousins_FGA = list(center['FGA'][7:14])
DwightHoward_FGA = list(center['FGA'][14:21])
JoelEmbiid_FGA = list(center['FGA'][21:28])
JusufNurkic_FGA = list(center['FGA'][28:35])
KarlAnthonyTowns_FGA = list(center['FGA'][35:42])
KevinLove_FGA = list(center['FGA'][42:49])
MarcGasol_FGA = list(center['FGA'][49:56])
NikolaJokic_FGA = list(center['FGA'][56:63])
NikolaVucevic_FGA = list(center['FGA'][63:71])

FieldGoalsAttempted = np.array([AndreDrummond_FGA, DeMarcusCousins_FGA, DwightHoward_FGA, JoelEmbiid_FGA, JusufNurkic_FGA, KarlAnthonyTowns_FGA, KevinLove_FGA, MarcGasol_FGA, NikolaJokic_FGA, NikolaVucevic_FGA])

# %%
FieldGoalsAttempted
# Out:
# array([[ 84, 124, 158, 139, 161, 172,  43],
#        [143, 251, 281, 189,   0,   0,   0],
#        [ 69, 131, 185, 155, 139, 185,  47],
#        [ 90, 210, 157, 184, 181, 234,   0],
#        [ 80, 222, 113, 175, 113, 177,  71],
#        [112, 209, 202, 216, 136, 222,  75],
#        [ 94, 190, 202, 115,   0,  70,  58],
#        [103, 207, 254, 158, 132, 154,  25],
#        [ 86, 155, 106, 207, 133, 208, 114],
#        [110, 203, 192,   0,  50, 228,  57]], dtype=int64)

# %% [markdown]
# ### Rebounds

# %%
AndreDrummond_Rebound = list(center['REB'][0:7])
DeMarcusCousins_Rebound = list(center['REB'][7:14])
DwightHoward_Rebound = list(center['REB'][14:21])
JoelEmbiid_Rebound = list(center['REB'][21:28])
JusufNurkic_Rebound = list(center['REB'][28:35])
KarlAnthonyTowns_Rebound = list(center['REB'][35:42])
KevinLove_Rebound = list(center['REB'][42:49])
MarcGasol_Rebound = list(center['REB'][49:56])
NikolaJokic_Rebound = list(center['REB'][56:63])
NikolaVucevic_Rebound = list(center['REB'][63:71])

Rebounds = np.array([AndreDrummond_Rebound, DeMarcusCousins_Rebound, DwightHoward_Rebound, JoelEmbiid_Rebound, JusufNurkic_Rebound, KarlAnthonyTowns_Rebound, KevinLove_Rebound, MarcGasol_Rebound, NikolaJokic_Rebound, NikolaVucevic_Rebound])

# %%
Rebounds
# Out:
# array([[113, 190, 227, 188, 212, 254,  63],
#        [ 95, 167, 189, 166,   0,   0,   0],
#        [104, 150, 189, 193, 133, 170,  73],
#        [ 60, 144,  91, 122, 117, 156,   0],
#        [ 54, 119,  71, 152,  86, 154,  72],
#        [ 83, 174, 170, 229, 128, 165,  63],
#        [ 78, 148, 131,  92,   0,  49,  48],
#        [ 68, 110, 137, 102,  74,  85,  16],
#        [ 79, 144,  73, 162, 113, 158,  74],
#        [ 60, 124, 131,   0,  28, 133,  47]], dtype=int64)

# %% [markdown]
# ### Blocks

# %%
AndreDrummond_Block = list(center['BLK'][0:7])
DeMarcusCousins_Block = list(center['BLK'][7:14])
DwightHoward_Block = list(center['BLK'][14:21])
JoelEmbiid_Block = list(center['BLK'][21:28])
JusufNurkic_Block = list(center['BLK'][28:35])
KarlAnthonyTowns_Block = list(center['BLK'][35:42])
KevinLove_Block = list(center['BLK'][42:49])
MarcGasol_Block = list(center['BLK'][49:56])
NikolaJokic_Block = list(center['BLK'][56:63])
NikolaVucevic_Block = list(center['BLK'][63:71])

Block = np.array([AndreDrummond_Block, DeMarcusCousins_Block, DwightHoward_Block, JoelEmbiid_Block, JusufNurkic_Block, KarlAnthonyTowns_Block, KevinLove_Block, MarcGasol_Block, NikolaJokic_Block, NikolaVucevic_Block])

# %%
Block
# Out:
# array([[ 8, 15, 20, 23, 26, 32,  3],
#        [15, 18, 21, 22,  0,  0,  0],
#        [12, 11, 21, 41, 18, 20,  8],
#        [ 6, 26, 21, 16, 17, 25,  0],
#        [ 6, 21, 14, 19, 15, 28,  8],
#        [14, 14, 32, 20, 14, 17,  4],
#        [ 3,  7,  4,  6,  0,  2,  2],
#        [14, 18, 25, 16, 14, 12,  2],
#        [ 2, 11,  9, 10,  9, 13,  7],
#        [10, 10, 18,  0,  6, 11,  7]], dtype=int64)

# %% [markdown]
# ### Double Double

# %%
AndreDrummond_Double = list(center['DD2'][0:7])
DeMarcusCousins_Double = list(center['DD2'][7:14])
DwightHoward_Double = list(center['DD2'][14:21])
JoelEmbiid_Double = list(center['DD2'][21:28])
JusufNurkic_Double = list(center['DD2'][28:35])
KarlAnthonyTowns_Double = list(center['DD2'][35:42])
KevinLove_Double = list(center['DD2'][42:49])
MarcGasol_Double = list(center['DD2'][49:56])
NikolaJokic_Double = list(center['DD2'][56:63])
NikolaVucevic_Double = list(center['DD2'][63:71])

DoubleDouble = np.array([AndreDrummond_Double, DeMarcusCousins_Double, DwightHoward_Double, JoelEmbiid_Double, JusufNurkic_Double, KarlAnthonyTowns_Double, KevinLove_Double, MarcGasol_Double, NikolaJokic_Double, NikolaVucevic_Double])

# %%
DoubleDouble
# Out:
# array([[ 5,  9, 11,  9, 12, 12,  4],
#        [ 7,  9, 11, 11,  0,  0,  0],
#        [ 4,  8,  8, 12,  6, 10,  5],
#        [ 2,  9,  4,  8,  8,  7,  0],
#        [ 2,  4,  1,  5,  3,  8,  4],
#        [ 6, 12, 11, 16,  9, 10,  4],
#        [ 6,  8,  8,  5,  0,  2,  2],
#        [ 4,  6,  5,  5,  2,  3,  0],
#        [ 3,  8,  2,  7,  6,  7,  5],
#        [ 3,  7,  8,  0,  0,  8,  3]], dtype=int64)

# %% [markdown]
# ______________________________________________________________

# %% [markdown]
# # Visualization

# %%
#Importing Numpy
import numpy as np
#Importing Matplotlib
import matplotlib.pyplot as plt
#Display Vizualization in the same page
# %matplotlib inline
#Increase the size of the graph
plt.rcParams['figure.figsize'] = 15,7
#Ignoring the Warnings
import warnings
warnings.filterwarnings('ignore')
#To remove the line - <matplotlib.lines.Line2D at 0x1978bdccc88>
plt.show()

# %% [markdown]
# ### Example

# %%
plt.plot(Games[0], c='Black', ls='--', marker='s', ms=7, label=Players[0])
plt.plot(Games[1], c='Red', ls='--', marker='o', ms=7, label=Players[1])
plt.plot(Games[2], c='Green', ls='--', marker='^', ms=7, label=Players[2])
plt.plot(Games[3], c='Blue', ls='--', marker='D', ms=7, label=Players[3])
plt.plot(Games[4], c='Magenta', ls='--', marker='s', ms=7, label=Players[4])
plt.plot(Games[5], c='Black', ls='--', marker='o', ms=7, label=Players[5])
plt.plot(Games[6], c='Red', ls='--', marker='^', ms=7, label=Players[6])
plt.plot(Games[7], c='Green', ls='--', marker='D', ms=7, label=Players[7])
plt.plot(Games[8], c='Blue', ls='--', marker='s', ms=7, label=Players[8])
plt.plot(Games[9], c='Magenta', ls='--', marker='o', ms=7, label=Players[9])
plt.xticks(list(range(0,7)), Month)
plt.legend(loc='upper left', bbox_to_anchor=(1,1))
plt.show()

# %% [markdown]
# ### Tally - Western Conference

# %%
Cousins = []
Towns = []
Gasol = []
Jokic = []
Nurkic = []

# %% [markdown]
# ### Tally - Eastern Conference

# %%
Vucevic = []
Love = []
Embiid = []
Drummond = []
Howard = []

# %% [markdown]
# ### List for Players from from Western and Eastern Conference

# %%
PlayerWC = ["DeMarcusCousins","KarlAnthonyTowns","MarcGasol","NikolaJokic","JusufNurkic"]
PlayerEC = ["NikolaVucevic","KevinLove","JoelEmbiid","AndreDrummond","DwightHoward"]

# %% [markdown]
# ### Function for Minutes Played

# %%
def Minutesplot(playerlist=Players):
    Col = {"AndreDrummond":"Black","DeMarcusCousins":"Red","DwightHoward":"Green","JoelEmbiid":"Blue","JusufNurkic":"Magenta","KarlAnthonyTowns":"Black","KevinLove":"Red","MarcGasol":"Green","NikolaJokic":"Blue","NikolaVucevic":"Magenta"}
    Mrk = {"AndreDrummond":"s","DeMarcusCousins":"o","DwightHoward":"^","JoelEmbiid":"D","JusufNurkic":"s","KarlAnthonyTowns":"o","KevinLove":"^","MarcGasol":"D","NikolaJokic":"s","NikolaVucevic":"o"} 
    for name in playerlist:        
        plt.plot(MinutesPlayed[PlayerD[name]], c=Col[name], ls='--', marker=Mrk[name], ms=7, label=name)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,7)), Month)
    plt.show()

# %% [markdown]
# ### Minutes Played - Western Conference

# %%
Minutesplot(PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Karl-Anthony Towns - 5 points
# #### 2. Nikola Jokic - 4 points
# #### 3. Marc Gasol - 3 points
# #### 4. Jusuf Nurkic - 2 points
# #### 5. DeMarcus Cousins - 1 point

# %%
Towns.extend([5])
Jokic.extend([4])
Gasol.extend([3])
Nurkic.extend([2])
Cousins.extend([1])

# %% [markdown]
# ### Minutes Played - Eastern Conference

# %%
Minutesplot(PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Andre Drummond - 5 points
# #### 2. Dwight Howard - 4 points
# #### 3. Joel Embiid - 3 points
# #### 4. Nikola Vucevic - 2 points
# #### 5. Kevin Love - 1 point

# %%
Drummond.extend([5])
Howard.extend([4])
Embiid.extend([3])
Vucevic.extend([2])
Love.extend([1])

# %% [markdown]
# ______________________________________________________________

# %% [markdown]
# ### Function for Points Scored

# %%
def Pointsplot(playerlist=Players):
    Col = {"AndreDrummond":"Black","DeMarcusCousins":"Red","DwightHoward":"Green","JoelEmbiid":"Blue","JusufNurkic":"Magenta","KarlAnthonyTowns":"Black","KevinLove":"Red","MarcGasol":"Green","NikolaJokic":"Blue","NikolaVucevic":"Magenta"}
    Mrk = {"AndreDrummond":"s","DeMarcusCousins":"o","DwightHoward":"^","JoelEmbiid":"D","JusufNurkic":"s","KarlAnthonyTowns":"o","KevinLove":"^","MarcGasol":"D","NikolaJokic":"s","NikolaVucevic":"o"} 
    for name in playerlist:        
        plt.plot(PointsMade[PlayerD[name]], c=Col[name], ls='--', marker=Mrk[name], ms=7, label=name)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,7)), Month)
    plt.show()

# %% [markdown]
# ### Points Scored - Western Conference

# %%
Pointsplot(PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Karl-Anthony Towns - 5 points
# #### 2. Nikola Jokic - 4 points
# #### 3. Marc Gasol - 3 points
# #### 4. DeMarcus Cousins - 2 points
# #### 5. Jusuf Nurkic - 1 point

# %%
Towns.extend([5])
Jokic.extend([4])
Gasol.extend([3])
Cousins.extend([2])
Nurkic.extend([1])

# %% [markdown]
# ### Points Scored - Eastern Conference

# %%
Pointsplot(PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Andre Drummond - 5 points
# #### 2. Dwight Howard - 4 points
# #### 3. Joel Embiid - 3 points
# #### 4. Nikola Vucevic - 2 points
# #### 5. Kevin Love - 1 points

# %%
Drummond.extend([5])
Howard.extend([4])
Embiid.extend([3])
Vucevic.extend([2])
Love.extend([1])

# %% [markdown]
# _________________________________________________

# %% [markdown]
# ### Function for Field Goals Made

# %%
def FieldGoalsplot(playerlist=Players):
    Col = {"AndreDrummond":"Black","DeMarcusCousins":"Red","DwightHoward":"Green","JoelEmbiid":"Blue","JusufNurkic":"Magenta","KarlAnthonyTowns":"Black","KevinLove":"Red","MarcGasol":"Green","NikolaJokic":"Blue","NikolaVucevic":"Magenta"}
    Mrk = {"AndreDrummond":"s","DeMarcusCousins":"o","DwightHoward":"^","JoelEmbiid":"D","JusufNurkic":"s","KarlAnthonyTowns":"o","KevinLove":"^","MarcGasol":"D","NikolaJokic":"s","NikolaVucevic":"o"} 
    for name in playerlist:        
        plt.plot(FieldGoals[PlayerD[name]], c=Col[name], ls='--', marker=Mrk[name], ms=7, label=name)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,7)), Month)
    plt.show()

# %% [markdown]
# ### Field Goals - Western Conference

# %%
FieldGoalsplot(PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Karl-Anthony Towns - 5 points
# #### 2. Nikola Jokic - 4 points
# #### 3. Jusuf Nurkic - 3 points
# #### 4. Marc Gasol - 2 points
# #### 5. DeMarcus Cousins - 1 point

# %%
Towns.extend([5])
Jokic.extend([4])
Gasol.extend([2])
Nurkic.extend([3])
Cousins.extend([1])

# %% [markdown]
# ### Field Goals - Eastern Conference

# %%
FieldGoalsplot(PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Joel Embiid - 5 points
# #### 2. Dwight Howard - 4 points
# #### 3. Andre Drummond - 3 points
# #### 4. Nikola Vucevic - 2 points
# #### 5. Kevin Love - 1 point

# %%
Drummond.extend([3])
Howard.extend([4])
Embiid.extend([5])
Vucevic.extend([2])
Love.extend([1])

# %% [markdown]
# ________________________________________________

# %% [markdown]
# ### Function for Rebounds

# %%
def Reboundsplot(playerlist=Players):
    Col = {"AndreDrummond":"Black","DeMarcusCousins":"Red","DwightHoward":"Green","JoelEmbiid":"Blue","JusufNurkic":"Magenta","KarlAnthonyTowns":"Black","KevinLove":"Red","MarcGasol":"Green","NikolaJokic":"Blue","NikolaVucevic":"Magenta"}
    Mrk = {"AndreDrummond":"s","DeMarcusCousins":"o","DwightHoward":"^","JoelEmbiid":"D","JusufNurkic":"s","KarlAnthonyTowns":"o","KevinLove":"^","MarcGasol":"D","NikolaJokic":"s","NikolaVucevic":"o"} 
    for name in playerlist:        
        plt.plot(Rebounds[PlayerD[name]], c=Col[name], ls='--', marker=Mrk[name], ms=7, label=name)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,7)), Month)
    plt.show()

# %% [markdown]
# ### Rebounds - Western Conference

# %%
Reboundsplot(PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Karl-Anthony Towns - 5 points
# #### 2. Nikola Jokic - 4 points
# #### 3. Jusuf Nurkic - 3 points
# #### 4. DeMarcus Cousins - 2 points
# #### 5. Marc Gasol - 1 point

# %%
Towns.extend([5])
Jokic.extend([4])
Gasol.extend([1])
Nurkic.extend([3])
Cousins.extend([2])

# %% [markdown]
# ### Rebounds - Eastern Conference

# %%
Reboundsplot(PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Joel Embiid - 5 points
# #### 2. Dwight Howard - 4 points
# #### 3. Andre Drummond - 3 points
# #### 4. Nikola Vucevic - 2 points
# #### 5. Kevin Love - 1 point

# %%
Drummond.extend([3])
Howard.extend([4])
Embiid.extend([5])
Vucevic.extend([2])
Love.extend([1])

# %% [markdown]
# ____________________________________________

# %% [markdown]
# ### Function for Blocks

# %%
def Blocksplot(playerlist=Players):
    Col = {"AndreDrummond":"Black","DeMarcusCousins":"Red","DwightHoward":"Green","JoelEmbiid":"Blue","JusufNurkic":"Magenta","KarlAnthonyTowns":"Black","KevinLove":"Red","MarcGasol":"Green","NikolaJokic":"Blue","NikolaVucevic":"Magenta"}
    Mrk = {"AndreDrummond":"s","DeMarcusCousins":"o","DwightHoward":"^","JoelEmbiid":"D","JusufNurkic":"s","KarlAnthonyTowns":"o","KevinLove":"^","MarcGasol":"D","NikolaJokic":"s","NikolaVucevic":"o"} 
    for name in playerlist:        
        plt.plot(Block[PlayerD[name]], c=Col[name], ls='--', marker=Mrk[name], ms=7, label=name)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,7)), Month)
    plt.show()

# %% [markdown]
# ### Blocks - Western Conference

# %%
Blocksplot(PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Karl-Anthony Towns - 5 points
# #### 2. Jusuf Nurkic - 4 points
# #### 3. Marc Gasol - 3 points
# #### 4. DeMarcus Cousins - 2 points
# #### 5. Nikola Jokic - 1 points

# %%
Towns.extend([5])
Jokic.extend([1])
Gasol.extend([3])
Nurkic.extend([4])
Cousins.extend([2])

# %% [markdown]
# ### Blocks - Eastern Conference

# %%
Blocksplot(PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Dwight Howard - 5 points
# #### 2. Andre Drummond - 4 points
# #### 3. Joel Embiid - 3 points
# #### 4. Nikola Vucevic - 2 points
# #### 5. Kevin Love - 1 point

# %%
Drummond.extend([4])
Howard.extend([5])
Embiid.extend([3])
Vucevic.extend([2])
Love.extend([1])

# %% [markdown]
# _____________________________________________________

# %% [markdown]
# ### Function for Double Double

# %%
def Doubledoubleplot(playerlist=Players):
    Col = {"AndreDrummond":"Black","DeMarcusCousins":"Red","DwightHoward":"Green","JoelEmbiid":"Blue","JusufNurkic":"Magenta","KarlAnthonyTowns":"Black","KevinLove":"Red","MarcGasol":"Green","NikolaJokic":"Blue","NikolaVucevic":"Magenta"}
    Mrk = {"AndreDrummond":"s","DeMarcusCousins":"o","DwightHoward":"^","JoelEmbiid":"D","JusufNurkic":"s","KarlAnthonyTowns":"o","KevinLove":"^","MarcGasol":"D","NikolaJokic":"s","NikolaVucevic":"o"} 
    for name in playerlist:        
        plt.plot(DoubleDouble[PlayerD[name]], c=Col[name], ls='--', marker=Mrk[name], ms=7, label=name)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,7)), Month)
    plt.show()

# %% [markdown]
# ### Double Double - Western Conference

# %%
Doubledoubleplot(PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Karl-Anthony Towns - 5 points
# #### 2. Nikola Jokic - 4 points (Tie)
# #### 2. DeMarcus Cousins - 4 points (Tie)
# #### 4. Jusuf Nurkic - 2 points
# #### 5. Marc Gasol - 1 point

# %%
Towns.extend([5])
Jokic.extend([4])
Gasol.extend([1])
Nurkic.extend([2])
Cousins.extend([4])

# %% [markdown]
# ### Double Double - Eastern Conference

# %%
Doubledoubleplot(PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Andre Drummond - 5 points
# #### 2. Dwight Howard - 4 points
# #### 3. Joel Embiid - 3 points
# #### 4. Kevin Love - 2 points
# #### 5. Nikola Vucevic - 1 point

# %%
Drummond.extend([5])
Howard.extend([4])
Embiid.extend([3])
Vucevic.extend([1])
Love.extend([2])

# %% [markdown]
# ______________________________________________________________

# %% [markdown]
# ### Function for Manual Calculation

# %%
def Calculation(data, playerlist=Players):
    Col = {"AndreDrummond":"Black","DeMarcusCousins":"Red","DwightHoward":"Green","JoelEmbiid":"Blue","JusufNurkic":"Magenta","KarlAnthonyTowns":"Black","KevinLove":"Red","MarcGasol":"Green","NikolaJokic":"Blue","NikolaVucevic":"Magenta"}
    Mrk = {"AndreDrummond":"s","DeMarcusCousins":"o","DwightHoward":"^","JoelEmbiid":"D","JusufNurkic":"s","KarlAnthonyTowns":"o","KevinLove":"^","MarcGasol":"D","NikolaJokic":"s","NikolaVucevic":"o"} 
    for name in playerlist:        
        plt.plot(data[PlayerD[name]], c=Col[name], ls='--', marker=Mrk[name], ms=7, label=name)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,7)), Month)
    plt.show()

# %% [markdown]
# ### Shooting Accuracy - Western Conference

# %%
Calculation(FieldGoals/FieldGoalsAttempted, PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Karl-Anthony Towns - 5 points
# #### 2. Nikola Jokic - 4 points
# #### 3. Jusuf Nurkic - 3 points
# #### 4. Marc Gasol -  2 points
# #### 5. DeMarcus Cousins - 1 point

# %%
Towns.extend([5])
Jokic.extend([4])
Gasol.extend([2])
Nurkic.extend([3])
Cousins.extend([1])

# %% [markdown]
# ### Shooting Accuracy - Eastern Conference

# %%
Calculation(FieldGoals/FieldGoalsAttempted, PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Dwight Howard - 5 points
# #### 2. Andre Drummond - 4 points
# #### 3. Joel Embiid - 3 points
# #### 4. Nikola Vucevic - 2 points
# #### 5. Kevin Love - 1 point

# %%
Drummond.extend([4])
Howard.extend([5])
Embiid.extend([3])
Vucevic.extend([2])
Love.extend([1])

# %% [markdown]
# _________________________________________________________

# %% [markdown]
# ### Points/Minutes - Western Conference

# %%
Calculation(PointsMade/MinutesPlayed, PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Karl-Anthony Towns - 5 points
# #### 2. Nikola Jokic - 4 points
# #### 3. Jusuf Nurkic -  3 points
# #### 4. Marc Gasol - 2 points
# #### 5. DeMarcus Cousins - 1 point

# %%
Towns.extend([5])
Jokic.extend([4])
Gasol.extend([2])
Nurkic.extend([3])
Cousins.extend([1])

# %% [markdown]
# ### Points/Minutes - Eastern Conference

# %%
Calculation(PointsMade/MinutesPlayed, PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Joel Embiid - 5 points
# #### 2. Kevin Love - 4 points
# #### 3. Nikola Vucevic - 3 points
# #### 4. Dwight Howard - 2 points
# #### 5. Andre Drummond - 1 point

# %%
Drummond.extend([1])
Howard.extend([2])
Embiid.extend([5])
Vucevic.extend([3])
Love.extend([4])

# %% [markdown]
# _______________________________________

# %% [markdown]
# ### Player Defensive Efficiency - Western Conference

# %%
Calculation((Block + Rebounds)/MinutesPlayed, PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Jusuf Nurkic - 5 points
# #### 2. Karl-Anthony Towns - 4 points
# #### 3. Nikola Jokic - 3 points
# #### 4. DeMarcus Cousins - 2 points
# #### 5. Marc Gasol - 1 point

# %%
Towns.extend([4])
Jokic.extend([3])
Gasol.extend([1])
Nurkic.extend([5])
Cousins.extend([2])

# %% [markdown]
# ### Player Defensive Efficiency - Eastern Conference

# %%
Calculation((Block + Rebounds)/MinutesPlayed, PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Andre Drummond - 5 points
# #### 2. Dwight Howard - 4 points
# #### 3. Joel Embiid - 3 points
# #### 4. Nikola Vucevic - 2 points
# #### 5. Kevin Love - 1 point

# %%
Drummond.extend([5])
Howard.extend([4])
Embiid.extend([3])
Vucevic.extend([2])
Love.extend([1])

# %% [markdown]
# _________________________________________________________________________________________

# %% [markdown]
# _______________________________________________________________________

# %% [markdown]
# ## Final Rankings - Western Conference

# %%
#Tallying up the points
Towns_tally = sum(Towns)
Nurkic_tally = sum(Nurkic)
Jokic_tally = sum(Jokic)
Cousins_tally = sum(Cousins)
Gasol_tally = sum(Gasol)

#X-Axis (Labels)
players_label = ['Karl-Anthony Towns', 'Jusuf Nurkic', 'Nikola Jokic', 'DeMarcus Cousins', 'Marc Gasol']
#Converting the X-Axis into an array
players_label_arr = np.array(players_label)

#Y-Axis (Values for the labels)
tally = [Towns_tally, Nurkic_tally, Jokic_tally, Cousins_tally, Gasol_tally]

#Plotting the Bar
plt.bar(players_label_arr, tally)

#Labelling X and Y axes
plt.xlabel('Player Names', fontsize = 20, color='DarkBlue')
plt.ylabel('Total Points', fontsize = 20, color='DarkBlue')

#The Title
plt.title("WC Center - Final Rankings", fontsize=35, color="DarkBlue", fontname="Console")

#Displaying the Bar
plt.show()

# %% [markdown]
# ### 1. Karl-Anthony Towns
# ### 2. Nikola Jokic
# ### 3. Jusuf Nurkic
# ### 4. Marc Gasol
# ### 5. DeMarcus Cousins

# %% [markdown]
# ## First Choice Center (Western Conference): Karl-Anthony Towns

# %% [markdown]
# ![Karl-Anthony Towns](https://s.yimg.com/ny/api/res/1.2/k64s0Vd7DwqOwN2V0EKoag--/YXBwaWQ9aGlnaGxhbmRlcjtzbT0xO3c9ODAw/http://media.zenfs.com/en-GB/homerun/business_insider_uk_non_finance_744/89f953560a249d361d4b307bcabfcbba)

# %% [markdown]
# ## Reserve Center (Western Conference): Nikola Jokic

# %% [markdown]
# ![Nikola Jokic](http://www.dnevno.rs/images/news/2017/10/24/47441-nikola-jokic-800x600.jpg)

# %% [markdown]
# _____________________________________________________________________

# %% [markdown]
# ## Final Rankings - Eastern Conference

# %%
#Tallying up the points
Drummond_tally = sum(Drummond)
Howard_tally = sum(Howard)
Embiid_tally = sum(Embiid)
Vucevic_tally = sum(Vucevic)
Love_tally = sum(Love)

#X-Axis (Labels)
players_label = ['Andre Drummond', 'Dwight Howard', 'Joel Embiid', 'Nikola Vucevic', 'Kevin Love']
#Converting the X-Axis into an array
players_label_arr = np.array(players_label)

#Y-Axis (Values for the labels)
tally = [Drummond_tally, Howard_tally, Embiid_tally, Vucevic_tally, Love_tally]

#Plotting the Bar
plt.bar(players_label_arr, tally)

#Labelling X and Y axes
plt.xlabel('Player Names', fontsize = 20, color='DarkBlue')
plt.ylabel('Total Points', fontsize = 20, color='DarkBlue')

#The Title
plt.title("EC Center - Final Rankings", fontsize=35, color="DarkBlue", fontname="Console")

#Displaying the Bar
plt.show()

# %% [markdown]
# ### 1. Dwight Howard
# ### 2. Andre Drummond
# ### 3. Joel Embiid
# ### 4. Nikola Vucevic
# ### 5. Kevin Love

# %% [markdown]
# ## First Choice Center (Eastern Conference) - Dwight Howard

# %% [markdown]
# ![Dwight Howard](https://static.businessinsider.com/image/4ffb1e84eab8ea9411000014/image.jpg)

# %% [markdown]
# ## Second Choice Center (Eastern Conference) - Andre Drummond

# %% [markdown]
# ![Andre Drummond](https://thesportspost.com/wp-content/uploads/2017/07/why-andre-drummond-is-the-35th-best-player-in-the-nba-800x600.jpg)
