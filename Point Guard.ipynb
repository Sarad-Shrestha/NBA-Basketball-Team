# %% [markdown]
# # Point Guard

# %% [markdown]
# ### Months Played (Regular Season - 17/18)

# %%
Month = ["October","November","December","January","February","March","April"]
MonthD = {"October":0,"November":1,"December":2,"January":3,"February":4,"March":5,"April":6}

# %% [markdown]
# ### Player List

# %%
Players = ["DamianLillard", "DennisSchroder", "EricBledsoe", "GoranDragic", "JamesHarden", "JrueHoliday", "KembaWalker", "KyrieIrving", "RussellWestbrook", "StephenCurry"]
PlayerD = {"DamianLillard":0, "DennisSchroder":1, "EricBledsoe":2, "GoranDragic":3, "JamesHarden":4, "JrueHoliday":5, "KembaWalker":6, "KyrieIrving":7, "RussellWestbrook":8, "StephenCurry":9}

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Importing the CSV File

# %%
point_guard = pd.read_csv('C:\\Users\\Sarad\\Desktop\\Project\\Point_Guard.csv')

# %%
point_guard
# Out:
#                PLAYER TEAM  GP  MIN  PTS  FGM  FGA  3PM  3PA  FTM  FTA  AST  \
# 0      Damian Lillard  POR   7  247  170   52  131   18   48   48   54   40
# 1      Damian Lillard  POR  15  557  388  123  286   37  119  105  112   95
# 2      Damian Lillard  POR   9  345  224   76  183   32   83   40   42   62
# 3      Damian Lillard  POR  13  452  326  107  213   45  105   67   76   91
# 4      Damian Lillard  POR  10  370  314  104  216   32   90   74   80   67
# 5      Damian Lillard  POR  14  518  390  114  282   47  134  115  126   91
# 6      Damian Lillard  POR   5  180  150   45  104   16   50   44   48   35
# 7     Dennis Schroder  ATL   5  165  111   44  101    5   18   18   20   34
# 8     Dennis Schroder  ATL  14  446  271  106  226   18   49   41   47   93
# 9     Dennis Schroder  ATL  14  454  270  108  249   14   54   40   48   98
# 10    Dennis Schroder  ATL  15  446  280  104  259   15   62   57   65   90
# ...

# %% [markdown]
# ### Games

# %%
DamianLillard_Games = list(point_guard['GP'][0:7])
DennisSchroder_Games = list(point_guard['GP'][7:14])
EricBledsoe_Games = list(point_guard['GP'][14:21])
GoranDragic_Games = list(point_guard['GP'][21:28])
JamesHarden_Games = list(point_guard['GP'][28:35])
JrueHoliday_Games = list(point_guard['GP'][35:42])
KembaWalker_Games = list(point_guard['GP'][42:49])
KyrieIrving_Games = list(point_guard['GP'][49:56])
RussellWestbrook_Games = list(point_guard['GP'][56:63])
StephenCurry_Games = list(point_guard['GP'][63:71])

Games = np.array([DamianLillard_Games, DennisSchroder_Games, EricBledsoe_Games, GoranDragic_Games, JamesHarden_Games, JrueHoliday_Games, KembaWalker_Games, KyrieIrving_Games, RussellWestbrook_Games, StephenCurry_Games])

# %%
Games
# Out:
# array([[ 7, 15,  9, 13, 10, 14,  5],
#        [ 5, 14, 14, 15, 10,  9,  0],
#        [ 3, 10, 14, 15, 11, 15,  6],
#        [ 6, 15, 12, 13, 10, 16,  3],
#        [ 8, 13, 14,  7, 12, 13,  5],
#        [ 7, 14, 15, 14, 11, 14,  6],
#        [ 7, 12, 15, 14, 12, 15,  5],
#        [ 7, 15, 16, 10,  9,  3,  0],
#        [ 7, 13, 17, 14, 10, 14,  5],
#        [ 8, 12,  4, 12, 11,  4,  0]], dtype=int64)

# %% [markdown]
# ### Minutes Played

# %%
DamianLillard_Minutes = list(point_guard['MIN'][0:7])
DennisSchroder_Minutes = list(point_guard['MIN'][7:14])
EricBledsoe_Minutes = list(point_guard['MIN'][14:21])
GoranDragic_Minutes = list(point_guard['MIN'][21:28])
JamesHarden_Minutes = list(point_guard['MIN'][28:35])
JrueHoliday_Minutes = list(point_guard['MIN'][35:42])
KembaWalker_Minutes = list(point_guard['MIN'][42:49])
KyrieIrving_Minutes = list(point_guard['MIN'][49:56])
RussellWestbrook_Minutes = list(point_guard['MIN'][56:63])
StephenCurry_Minutes = list(point_guard['MIN'][63:71])

MinutesPlayed = np.array([DamianLillard_Minutes, DennisSchroder_Minutes, EricBledsoe_Minutes, GoranDragic_Minutes, JamesHarden_Minutes, JrueHoliday_Minutes, KembaWalker_Minutes, KyrieIrving_Minutes, RussellWestbrook_Minutes, StephenCurry_Minutes])

# %%
MinutesPlayed
# Out:
# array([[247, 557, 345, 452, 370, 518, 180],
#        [165, 446, 454, 446, 295, 271,   0],
#        [ 83, 302, 459, 444, 362, 480, 192],
#        [208, 479, 344, 433, 319, 512,  82],
#        [291, 464, 517, 246, 411, 451, 172],
#        [258, 500, 554, 534, 396, 482, 202],
#        [243, 424, 516, 491, 408, 523, 130],
#        [242, 455, 534, 355, 264,  81,   0],
#        [233, 474, 639, 489, 374, 515, 190],
#        [265, 387, 123, 412, 358,  85,   0]], dtype=int64)

# %% [markdown]
# ### Points

# %%
DamianLillard_Points = list(point_guard['PTS'][0:7])
DennisSchroder_Points = list(point_guard['PTS'][7:14])
EricBledsoe_Points = list(point_guard['PTS'][14:21])
GoranDragic_Points = list(point_guard['PTS'][21:28])
JamesHarden_Points = list(point_guard['PTS'][28:35])
JrueHoliday_Points = list(point_guard['PTS'][35:42])
KembaWalker_Points = list(point_guard['PTS'][42:49])
KyrieIrving_Points = list(point_guard['PTS'][49:56])
RussellWestbrook_Points = list(point_guard['PTS'][56:63])
StephenCurry_Points = list(point_guard['PTS'][63:71])

PointsMade = np.array([DamianLillard_Points, DennisSchroder_Points, EricBledsoe_Points, GoranDragic_Points, JamesHarden_Points, JrueHoliday_Points, KembaWalker_Points, KyrieIrving_Points, RussellWestbrook_Points, StephenCurry_Points])

# %%
PointsMade
# Out:
# array([[170, 388, 224, 326, 314, 390, 150],
#        [111, 271, 270, 280, 185, 184,   0],
#        [ 47, 167, 270, 222, 213, 279, 115],
#        [119, 258, 166, 241, 195, 276,  41],
#        [208, 454, 470, 195, 361, 369, 134],
#        [105, 224, 324, 284, 234, 261, 105],
#        [171, 253, 312, 340, 307, 328,  59],
#        [152, 362, 427, 252, 225,  48,   0],
#        [137, 310, 472, 380, 220, 386, 123],
#        [224, 298, 122, 354, 255,  93,   0]], dtype=int64)

# %% [markdown]
# ### Field Goals

# %%
DamianLillard_FG = list(point_guard['FGM'][0:7])
DennisSchroder_FG = list(point_guard['FGM'][7:14])
EricBledsoe_FG = list(point_guard['FGM'][14:21])
GoranDragic_FG = list(point_guard['FGM'][21:28])
JamesHarden_FG = list(point_guard['FGM'][28:35])
JrueHoliday_FG = list(point_guard['FGM'][35:42])
KembaWalker_FG = list(point_guard['FGM'][42:49])
KyrieIrving_FG = list(point_guard['FGM'][49:56])
RussellWestbrook_FG = list(point_guard['FGM'][56:63])
StephenCurry_FG = list(point_guard['FGM'][63:71])

FieldGoals = np.array([DamianLillard_FG, DennisSchroder_FG, EricBledsoe_FG, GoranDragic_FG, JamesHarden_FG, JrueHoliday_FG, KembaWalker_FG, KyrieIrving_FG, RussellWestbrook_FG, StephenCurry_FG])

# %%
FieldGoals
# Out:
# array([[ 52, 123,  76, 107, 104, 114,  45],
#        [ 44, 106, 108, 104,  66,  72,   0],
#        [ 16,  61,  93,  79,  76, 102,  41],
#        [ 48,  89,  64,  92,  72, 102,  17],
#        [ 68, 132, 134,  62, 103, 112,  40],
#        [ 42,  89, 127, 111,  95, 109,  42],
#        [ 52,  87, 107, 114, 102, 107,  19],
#        [ 57, 130, 157,  92,  80,  18,   0],
#        [ 51, 104, 181, 152,  77, 148,  44],
#        [ 67,  96,  42, 109,  84,  30,   0]], dtype=int64)

# %% [markdown]
# ### Field Goals Attempted

# %%
DamianLillard_FGA = list(point_guard['FGA'][0:7])
DennisSchroder_FGA = list(point_guard['FGA'][7:14])
EricBledsoe_FGA = list(point_guard['FGA'][14:21])
GoranDragic_FGA = list(point_guard['FGA'][21:28])
JamesHarden_FGA = list(point_guard['FGA'][28:35])
JrueHoliday_FGA = list(point_guard['FGA'][35:42])
KembaWalker_FGA = list(point_guard['FGA'][42:49])
KyrieIrving_FGA = list(point_guard['FGA'][49:56])
RussellWestbrook_FGA = list(point_guard['FGA'][56:63])
StephenCurry_FGA = list(point_guard['FGA'][63:71])

FieldGoalsAttempted = np.array([DamianLillard_FGA, DennisSchroder_FGA, EricBledsoe_FGA, GoranDragic_FGA, JamesHarden_FGA, JrueHoliday_FGA, KembaWalker_FGA, KyrieIrving_FGA, RussellWestbrook_FGA, StephenCurry_FGA])

# %%
FieldGoalsAttempted
# Out:
# array([[131, 286, 183, 213, 216, 282, 104],
#        [101, 226, 249, 259, 155, 156,   0],
#        [ 40, 138, 202, 188, 144, 205,  72],
#        [ 95, 204, 164, 208, 155, 215,  34],
#        [161, 282, 298, 140, 230, 257,  81],
#        [ 92, 193, 242, 219, 192, 229,  77],
#        [112, 202, 271, 265, 217, 249,  47],
#        [129, 260, 315, 194, 151,  38,   0],
#        [108, 274, 404, 314, 189, 297, 101],
#        [136, 215,  72, 212, 175,  54,   0]], dtype=int64)

# %% [markdown]
# ### 3-Points Made

# %%
#3 Points Made
DamianLillard_3PM = list(point_guard['3PM'][0:7])
DennisSchroder_3PM = list(point_guard['3PM'][7:14])
EricBledsoe_3PM = list(point_guard['3PM'][14:21])
GoranDragic_3PM = list(point_guard['3PM'][21:28])
JamesHarden_3PM = list(point_guard['3PM'][28:35])
JrueHoliday_3PM = list(point_guard['3PM'][35:42])
KembaWalker_3PM = list(point_guard['3PM'][42:49])
KyrieIrving_3PM = list(point_guard['3PM'][49:56])
RussellWestbrook_3PM = list(point_guard['3PM'][56:63])
StephenCurry_3PM = list(point_guard['3PM'][63:71])

ThreePointsMade= np.array([DamianLillard_3PM, DennisSchroder_3PM, EricBledsoe_3PM, GoranDragic_3PM, JamesHarden_3PM, JrueHoliday_3PM, KembaWalker_3PM, KyrieIrving_3PM, RussellWestbrook_3PM, StephenCurry_3PM])

# %%
ThreePointsMade
# Out:
# array([[18, 37, 32, 45, 32, 47, 16],
#        [ 5, 18, 14, 15, 11, 13,  0],
#        [ 4, 11, 25, 22, 25, 27, 11],
#        [ 9, 29, 10, 19, 19, 21,  4],
#        [27, 67, 51, 26, 48, 31, 15],
#        [ 9, 17, 37, 18, 13, 18,  8],
#        [15, 30, 38, 48, 48, 46,  6],
#        [15, 33, 53, 29, 30,  6,  0],
#        [ 9, 30, 17, 13,  7, 15,  6],
#        [32, 38, 23, 62, 44, 13,  0]], dtype=int64)

# %% [markdown]
# ### 3-Points Attempted

# %%
DamianLillard_3PA = list(point_guard['3PA'][0:7])
DennisSchroder_3PA = list(point_guard['3PA'][7:14])
EricBledsoe_3PA = list(point_guard['3PA'][14:21])
GoranDragic_3PA = list(point_guard['3PA'][21:28])
JamesHarden_3PA = list(point_guard['3PA'][28:35])
JrueHoliday_3PA = list(point_guard['3PA'][35:42])
KembaWalker_3PA = list(point_guard['3PA'][42:49])
KyrieIrving_3PA = list(point_guard['3PA'][49:56])
RussellWestbrook_3PA = list(point_guard['3PA'][56:63])
StephenCurry_3PA = list(point_guard['3PA'][63:71])

ThreePointsAttempted = np.array([DamianLillard_3PA, DennisSchroder_3PA, EricBledsoe_3PA, GoranDragic_3PA, JamesHarden_3PA, JrueHoliday_3PA, KembaWalker_3PA, KyrieIrving_3PA, RussellWestbrook_3PA, StephenCurry_3PA])

# %%
ThreePointsAttempted
# Out:
# array([[ 48, 119,  83, 105,  90, 134,  50],
#        [ 18,  49,  54,  62,  38,  41,   0],
#        [ 13,  42,  78,  71,  57,  75,  24],
#        [ 23,  73,  37,  58,  43,  58,   8],
#        [ 78, 155, 139,  71, 129, 115,  35],
#        [ 27,  68,  87,  65,  39,  48,  22],
#        [ 39,  84, 118, 115,  99, 122,  24],
#        [ 44,  85, 121,  73,  67,  17,   0],
#        [ 25,  87,  73,  37,  45,  41,  18],
#        [ 83, 107,  41, 134, 107,  29,   0]], dtype=int64)

# %% [markdown]
# ### Free Throws Made

# %%
#Free Throw Made
DamianLillard_FTM = list(point_guard['FTM'][0:7])
DennisSchroder_FTM = list(point_guard['FTM'][7:14])
EricBledsoe_FTM = list(point_guard['FTM'][14:21])
GoranDragic_FTM = list(point_guard['FTM'][21:28])
JamesHarden_FTM = list(point_guard['FTM'][28:35])
JrueHoliday_FTM = list(point_guard['FTM'][35:42])
KembaWalker_FTM = list(point_guard['FTM'][42:49])
KyrieIrving_FTM = list(point_guard['FTM'][49:56])
RussellWestbrook_FTM = list(point_guard['FTM'][56:63])
StephenCurry_FTM = list(point_guard['FTM'][63:71])

FreeThrowMade = np.array([DamianLillard_FTM, DennisSchroder_FTM, EricBledsoe_FTM, GoranDragic_FTM, JamesHarden_FTM, JrueHoliday_FTM, KembaWalker_FTM, KyrieIrving_FTM, RussellWestbrook_FTM, StephenCurry_FTM])

# %%
FreeThrowMade
# Out:
# array([[ 48, 105,  40,  67,  74, 115,  44],
#        [ 18,  41,  40,  57,  42,  27,   0],
#        [ 11,  34,  59,  42,  36,  48,  22],
#        [ 14,  51,  28,  38,  32,  51,   3],
#        [ 45, 123, 151,  45, 107, 114,  39],
#        [ 12,  29,  33,  44,  31,  25,  13],
#        [ 52,  49,  60,  64,  55,  68,  15],
#        [ 23,  69,  60,  39,  35,   6,   0],
#        [ 26,  72,  93,  63,  59,  75,  29],
#        [ 58,  68,  15,  74,  43,  20,   0]], dtype=int64)

# %% [markdown]
# ### Free Throws Attempted

# %%
DamianLillard_FTA = list(point_guard['FTA'][0:7])
DennisSchroder_FTA = list(point_guard['FTA'][7:14])
EricBledsoe_FTA = list(point_guard['FTA'][14:21])
GoranDragic_FTA = list(point_guard['FTA'][21:28])
JamesHarden_FTA = list(point_guard['FTA'][28:35])
JrueHoliday_FTA = list(point_guard['FTA'][35:42])
KembaWalker_FTA = list(point_guard['FTA'][42:49])
KyrieIrving_FTA = list(point_guard['FTA'][49:56])
RussellWestbrook_FTA = list(point_guard['FTA'][56:63])
StephenCurry_FTA = list(point_guard['FTA'][63:71])

FreeThrowAttempted = np.array([DamianLillard_FTA, DennisSchroder_FTA, EricBledsoe_FTA, GoranDragic_FTA, JamesHarden_FTA, JrueHoliday_FTA, KembaWalker_FTA, KyrieIrving_FTA, RussellWestbrook_FTA, StephenCurry_FTA])

# %%
FreeThrowAttempted
# Out:
# array([[ 54, 112,  42,  76,  80, 126,  48],
#        [ 20,  47,  48,  65,  48,  37,   0],
#        [ 14,  48,  78,  52,  38,  65,  23],
#        [ 18,  63,  40,  52,  39,  55,   4],
#        [ 56, 138, 174,  55, 122, 136,  46],
#        [ 15,  33,  41,  56,  44,  33,  16],
#        [ 57,  61,  74,  76,  60,  76,  16],
#        [ 25,  81,  64,  46,  38,   7,   0],
#        [ 42,  94, 131,  92,  66, 104,  37],
#        [ 61,  73,  17,  85,  45,  21,   0]], dtype=int64)

# %% [markdown]
# ### Assists

# %%
DamianLillard_Assist = list(point_guard['AST'][0:7])
DennisSchroder_Assist = list(point_guard['AST'][7:14])
EricBledsoe_Assist = list(point_guard['AST'][14:21])
GoranDragic_Assist = list(point_guard['AST'][21:28])
JamesHarden_Assist = list(point_guard['AST'][28:35])
JrueHoliday_Assist = list(point_guard['AST'][35:42])
KembaWalker_Assist = list(point_guard['AST'][42:49])
KyrieIrving_Assist = list(point_guard['AST'][49:56])
RussellWestbrook_Assist = list(point_guard['AST'][56:63])
StephenCurry_Assist = list(point_guard['AST'][63:71])

Assists = np.array([DamianLillard_Assist, DennisSchroder_Assist, EricBledsoe_Assist, GoranDragic_Assist, JamesHarden_Assist, JrueHoliday_Assist, KembaWalker_Assist, KyrieIrving_Assist, RussellWestbrook_Assist, StephenCurry_Assist])

# %%
Assists
# Out:
# array([[ 40,  95,  62,  91,  67,  91,  35],
#        [ 34,  93,  98,  90,  41,  61,   0],
#        [  9,  50,  58,  56,  64,  93,  40],
#        [ 25,  70,  53,  72,  52,  75,  12],
#        [ 74, 131, 113,  63,  97, 109,  43],
#        [ 42,  77,  67,  76,  76, 100,  48],
#        [ 45,  73,  74,  87,  66,  77,  22],
#        [ 40,  74,  73,  53,  51,  15,   0],
#        [ 83, 106, 181, 143, 116, 130,  61],
#        [ 50,  77,  27,  80,  68,   8,   0]], dtype=int64)

# %% [markdown]
# ### Steals

# %%
DamianLillard_Steal = list(point_guard['STL'][0:7])
DennisSchroder_Steal = list(point_guard['STL'][7:14])
EricBledsoe_Steal = list(point_guard['STL'][14:21])
GoranDragic_Steal = list(point_guard['STL'][21:28])
JamesHarden_Steal = list(point_guard['STL'][28:35])
JrueHoliday_Steal = list(point_guard['STL'][35:42])
KembaWalker_Steal = list(point_guard['STL'][42:49])
KyrieIrving_Steal = list(point_guard['STL'][49:56])
RussellWestbrook_Steal = list(point_guard['STL'][56:63])
StephenCurry_Steal = list(point_guard['STL'][63:71])

Steals = np.array([DamianLillard_Steal, DennisSchroder_Steal, EricBledsoe_Steal, GoranDragic_Steal, JamesHarden_Steal, JrueHoliday_Steal, KembaWalker_Steal, KyrieIrving_Steal, RussellWestbrook_Steal, StephenCurry_Steal])

# %%
Steals
# Out:
# array([[10, 12,  9, 13, 12, 15,  6],
#        [ 9, 13, 15, 16, 14,  5,  0],
#        [ 4, 21, 27, 38, 18, 31, 10],
#        [ 4, 14, 14,  7,  7, 13,  4],
#        [14, 21, 28, 15, 19, 25,  4],
#        [11, 16, 19, 26, 15, 18, 18],
#        [ 6,  6, 26, 19, 16, 17,  1],
#        [17, 16, 14,  8,  6,  4,  0],
#        [ 9, 35, 31, 29, 15, 17, 11],
#        [13, 21,  6, 18, 17,  5,  0]], dtype=int64)

# %% [markdown]
# _____________________________________________________

# %% [markdown]
# # Vizualization

# %%
#Importing Numpy
import numpy as np
#Importing Matplotlib
import matplotlib.pyplot as plt
#Display Vizualization in the same page
# %matplotlib inline
#Increase the size of the graph
plt.rcParams['figure.figsize'] = 15,7
#Ignoring the Warnings
import warnings
warnings.filterwarnings('ignore')
#To remove the line - <matplotlib.lines.Line2D at 0x1978bdccc88>
plt.show()

# %% [markdown]
# ### Example

# %%
plt.plot(Games[0], c='Black', ls='--', marker='s', ms=7, label=Players[0])
plt.plot(Games[1], c='Red', ls='--', marker='o', ms=7, label=Players[1])
plt.plot(Games[2], c='Green', ls='--', marker='^', ms=7, label=Players[2])
plt.plot(Games[3], c='Blue', ls='--', marker='D', ms=7, label=Players[3])
plt.plot(Games[4], c='Magenta', ls='--', marker='s', ms=7, label=Players[4])
plt.plot(Games[5], c='Black', ls='--', marker='o', ms=7, label=Players[5])
plt.plot(Games[6], c='Red', ls='--', marker='^', ms=7, label=Players[6])
plt.plot(Games[7], c='Green', ls='--', marker='D', ms=7, label=Players[7])
plt.plot(Games[8], c='Blue', ls='--', marker='s', ms=7, label=Players[8])
plt.plot(Games[9], c='Magenta', ls='--', marker='o', ms=7, label=Players[9])
plt.xticks(list(range(0,7)), Month)
plt.legend(loc='upper left', bbox_to_anchor=(1,1))
plt.show()

# %% [markdown]
# ### Tally - Western Conference

# %%
Lillard = []
Harden = []
Holiday = []
Westbrook = []
Curry = []

# %% [markdown]
# ### Tally - Eastern Conference

# %%
Schroder = []
Bledsoe = []
Dragic = []
Walker = []
Irving = []

# %% [markdown]
# ### List for Players from from Western and Eastern Conference

# %%
PlayerWC = ["DamianLillard", "JamesHarden", "JrueHoliday", "RussellWestbrook", "StephenCurry"]
PlayerEC = ["DennisSchroder", "EricBledsoe", "GoranDragic", "KembaWalker", "KyrieIrving"]

# %% [markdown]
# ### Function for Minutes Played

# %%
def Minutesplot(playerlist):
    Col = {"DamianLillard":"Black", "DennisSchroder":"Red", "EricBledsoe":"Green", "GoranDragic":"Blue", "JamesHarden":"Cyan", "JrueHoliday":"Yellow", "KembaWalker":"Purple", "KyrieIrving":"Brown", "RussellWestbrook": "Orange", "StephenCurry":"Magenta"}
    Mrk = {"DamianLillard":"s","DennisSchroder":"o","EricBledsoe":"^","GoranDragic":"D","JamesHarden":"s","JrueHoliday":"o","KembaWalker":"^","KyrieIrving":"D","RussellWestbrook":"s","StephenCurry":"o"} 
    for name in playerlist:
        plt.plot(MinutesPlayed[PlayerD[name]], c=Col[name], ls='--', marker=Mrk[name], ms=7, label=name)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,7)), Month)
    plt.show()

# %% [markdown]
# ### Minutes Played - Western Conference

# %%
Minutesplot(PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Jrue Holiday - 5 points
# #### 2. Russell Westbrook - 4 points
# #### 3. Damian Lillard - 3 points
# #### 4. James Harden - 2 points
# #### 5. Stephen Curry - 1 point

# %%
Holiday.extend([5])
Westbrook.extend([4])
Lillard.extend([3])
Harden.extend([2])
Curry.extend([1])

# %% [markdown]
# ### Minutes Played - Eastern Conference

# %%
Minutesplot(PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Kemba Walker - 5 points
# #### 2. Goran Dragic - 4 points
# #### 3. Eric Bledsoe - 3 points
# #### 4. Dennis Schroder - 2 points
# #### 5. Kyrie Irving - 1 point

# %%
Walker.extend([5])
Dragic.extend([4])
Bledsoe.extend([3])
Schroder.extend([2])
Irving.extend([1])

# %% [markdown]
# _____________________________________________

# %% [markdown]
# ### Function for Points Scored

# %%
def Pointsplot(playerlist):
    Col = {"DamianLillard":"Black", "DennisSchroder":"Red", "EricBledsoe":"Green", "GoranDragic":"Blue", "JamesHarden":"Cyan", "JrueHoliday":"Yellow", "KembaWalker":"Purple", "KyrieIrving":"Brown", "RussellWestbrook": "Orange", "StephenCurry":"Magenta"}
    Mrk = {"DamianLillard":"s","DennisSchroder":"o","EricBledsoe":"^","GoranDragic":"D","JamesHarden":"s","JrueHoliday":"o","KembaWalker":"^","KyrieIrving":"D","RussellWestbrook":"s","StephenCurry":"o"} 
    for name in playerlist:
        plt.plot(PointsMade[PlayerD[name]], c=Col[name], ls='--', marker=Mrk[name], ms=7, label=name)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,7)), Month)
    plt.show()

# %% [markdown]
# ### Points Scored - Western Conference

# %%
Pointsplot(PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. James Harden - 5 points
# #### 2. Russell Westbrook - 4 points
# #### 3. Damian Lillard - 3 points
# #### 4. Jrue Holiday - 2 points
# #### 5. Stephen Curry - 1 point

# %%
Holiday.extend([2])
Westbrook.extend([4])
Lillard.extend([3])
Harden.extend([5])
Curry.extend([1])

# %% [markdown]
# ### Points Scored - Eastern Conference

# %%
Pointsplot(PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Kemba Walker - 5 points
# #### 2. Kyrie Irving - 4 points
# #### 3. Eric Bledsoe - 3 points
# #### 4. Dennis Schroder - 2 points
# #### 5. Goran Dragic - 1 point

# %%
Walker.extend([5])
Dragic.extend([1])
Bledsoe.extend([3])
Schroder.extend([2])
Irving.extend([4])

# %% [markdown]
# ____________________________________________________

# %% [markdown]
# ### Function for Field Goals Made

# %%
def FieldGoalsplot(playerlist):
    Col = {"DamianLillard":"Black", "DennisSchroder":"Red", "EricBledsoe":"Green", "GoranDragic":"Blue", "JamesHarden":"Cyan", "JrueHoliday":"Yellow", "KembaWalker":"Purple", "KyrieIrving":"Brown", "RussellWestbrook": "Orange", "StephenCurry":"Magenta"}
    Mrk = {"DamianLillard":"s","DennisSchroder":"o","EricBledsoe":"^","GoranDragic":"D","JamesHarden":"s","JrueHoliday":"o","KembaWalker":"^","KyrieIrving":"D","RussellWestbrook":"s","StephenCurry":"o"} 
    for name in playerlist:
        plt.plot(FieldGoals[PlayerD[name]], c=Col[name], ls='--', marker=Mrk[name], ms=7, label=name)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,7)), Month)
    plt.show()

# %% [markdown]
# ### Field Goals - Western Conference

# %%
FieldGoalsplot(PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Russell Westbrook - 5 points
# #### 2. James Harden - 4 points
# #### 3. Damian Lillard - 3 points
# #### 4. Jrue Holiday - 2 points
# #### 5. Stephen Curry - 1 point

# %%
Holiday.extend([2])
Westbrook.extend([5])
Lillard.extend([3])
Harden.extend([4])
Curry.extend([1])

# %% [markdown]
# ### Field Goals - Eastern Conference

# %%
FieldGoalsplot(PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Kemba Walker - 5 points
# #### 2. Kyrie Irving -  4 points
# #### 3. Dennis Schroder - 3 points
# #### 4. Goran Dragic - 2 points
# #### 5. Eric Bledsoe - 1 point

# %%
Walker.extend([5])
Dragic.extend([2])
Bledsoe.extend([1])
Schroder.extend([3])
Irving.extend([4])

# %% [markdown]
# _____________________________________________

# %% [markdown]
# ### Function for Three Points Made

# %%
def Threepointsplot(playerlist):
    Col = {"DamianLillard":"Black", "DennisSchroder":"Red", "EricBledsoe":"Green", "GoranDragic":"Blue", "JamesHarden":"Cyan", "JrueHoliday":"Yellow", "KembaWalker":"Purple", "KyrieIrving":"Brown", "RussellWestbrook": "Orange", "StephenCurry":"Magenta"}
    Mrk = {"DamianLillard":"s","DennisSchroder":"o","EricBledsoe":"^","GoranDragic":"D","JamesHarden":"s","JrueHoliday":"o","KembaWalker":"^","KyrieIrving":"D","RussellWestbrook":"s","StephenCurry":"o"} 
    for name in playerlist:
        plt.plot(ThreePointsMade[PlayerD[name]], c=Col[name], ls='--', marker=Mrk[name], ms=7, label=name)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,7)), Month)
    plt.show()

# %% [markdown]
# ### Three Points Made - Western Conference

# %%
Threepointsplot(PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. James Harden - 5 points
# #### 2. Damian Lillard - 4 points
# #### 3. Stephen Curry - 3 points
# #### 4. Jrue Holiday - 2 points
# #### 5. Russell Westbrook - 1 point

# %%
Holiday.extend([2])
Westbrook.extend([1])
Lillard.extend([4])
Harden.extend([5])
Curry.extend([3])

# %% [markdown]
# ### Three Points Made - Eastern Conference

# %%
Threepointsplot(PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Kemba Walker - 5 points
# #### 2. Kyrie Irving - 4 points
# #### 3. Eric Bledsoe - 3 points
# #### 4. Goran Dragic - 2 points
# #### 5. Dennis Schroder - 1 point

# %%
Walker.extend([5])
Dragic.extend([2])
Bledsoe.extend([3])
Schroder.extend([1])
Irving.extend([4])

# %% [markdown]
# ______________________________________________________

# %% [markdown]
# ### Function for Free Throws

# %%
def Freethrowsplot(playerlist):
    Col = {"DamianLillard":"Black", "DennisSchroder":"Red", "EricBledsoe":"Green", "GoranDragic":"Blue", "JamesHarden":"Cyan", "JrueHoliday":"Yellow", "KembaWalker":"Purple", "KyrieIrving":"Brown", "RussellWestbrook": "Orange", "StephenCurry":"Magenta"}
    Mrk = {"DamianLillard":"s","DennisSchroder":"o","EricBledsoe":"^","GoranDragic":"D","JamesHarden":"s","JrueHoliday":"o","KembaWalker":"^","KyrieIrving":"D","RussellWestbrook":"s","StephenCurry":"o"} 
    for name in playerlist:
        plt.plot(FreeThrowMade[PlayerD[name]], c=Col[name], ls='--', marker=Mrk[name], ms=7, label=name)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,7)), Month)
    plt.show()

# %% [markdown]
# ### Free Throws - Western Conference

# %%
Freethrowsplot(PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. James Harden - 5 points
# #### 2. Damian Lillard - 4 points
# #### 3. Russell Westbrook - 3 points
# #### 4. Stephen Curry - 2 points
# #### 5. Jrue Holiday - 1 point

# %%
Holiday.extend([1])
Westbrook.extend([3])
Lillard.extend([4])
Harden.extend([5])
Curry.extend([2])

# %% [markdown]
# ### Free Throws - Eastern Conference

# %%
Freethrowsplot(PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Kemba Walker - 5 points
# #### 2. Eric Bledsoe - 4 points
# #### 3. Kyrie Irving - 3 points
# #### 4. Dennis Schroder - 2 points
# #### 5. Goran Dragic - 1 point

# %%
Walker.extend([5])
Dragic.extend([1])
Bledsoe.extend([4])
Schroder.extend([2])
Irving.extend([3])

# %% [markdown]
# ______________________________________________

# %% [markdown]
# ### Function for Assists

# %%
def Assistsplot(playerlist):
    Col = {"DamianLillard":"Black", "DennisSchroder":"Red", "EricBledsoe":"Green", "GoranDragic":"Blue", "JamesHarden":"Cyan", "JrueHoliday":"Yellow", "KembaWalker":"Purple", "KyrieIrving":"Brown", "RussellWestbrook": "Orange", "StephenCurry":"Magenta"}
    Mrk = {"DamianLillard":"s","DennisSchroder":"o","EricBledsoe":"^","GoranDragic":"D","JamesHarden":"s","JrueHoliday":"o","KembaWalker":"^","KyrieIrving":"D","RussellWestbrook":"s","StephenCurry":"o"} 
    for name in playerlist:
        plt.plot(Assists[PlayerD[name]], c=Col[name], ls='--', marker=Mrk[name], ms=7, label=name)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,7)), Month)
    plt.show()

# %% [markdown]
# ### Assists - Western Conference

# %%
Assistsplot(PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Russell Westbrook - 5 points
# #### 2. James Harden - 4 points
# #### 3. Jrue Holiday - 3 points
# #### 4. Damian Lillard - 2 points
# #### 5. Stephen Curry - 1 point

# %%
Holiday.extend([3])
Westbrook.extend([5])
Lillard.extend([2])
Harden.extend([4])
Curry.extend([1])

# %% [markdown]
# ### Assists - Eastern Conference

# %%
Assistsplot(PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Kemba Walker - 5 points
# #### 2. Dennis Schroder - 4 points
# #### 3. Eric Bledsoe - 3 points
# #### 4. Goran Dragic - 2 points
# #### 5. Kyrie Irving - 1 point

# %%
Walker.extend([5])
Dragic.extend([2])
Bledsoe.extend([3])
Schroder.extend([4])
Irving.extend([1])

# %% [markdown]
# ___________________________________________

# %% [markdown]
# ### Function for Steals

# %%
def Stealsplot(playerlist):
    Col = {"DamianLillard":"Black", "DennisSchroder":"Red", "EricBledsoe":"Green", "GoranDragic":"Blue", "JamesHarden":"Cyan", "JrueHoliday":"Yellow", "KembaWalker":"Purple", "KyrieIrving":"Brown", "RussellWestbrook": "Orange", "StephenCurry":"Magenta"}
    Mrk = {"DamianLillard":"s","DennisSchroder":"o","EricBledsoe":"^","GoranDragic":"D","JamesHarden":"s","JrueHoliday":"o","KembaWalker":"^","KyrieIrving":"D","RussellWestbrook":"s","StephenCurry":"o"} 
    for name in playerlist:
        plt.plot(Steals[PlayerD[name]], c=Col[name], ls='--', marker=Mrk[name], ms=7, label=name)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,7)), Month)
    plt.show()

# %% [markdown]
# ### Steals - Western Conference

# %%
Stealsplot(PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Russell Westbrook - 5 points
# #### 2. James Harden - 4 points
# #### 3. Jrue Holiday - 3 points
# #### 4. Stephen Curry - 2 points
# #### 5. Damian Lillard - 1 point

# %%
Holiday.extend([3])
Westbrook.extend([5])
Lillard.extend([1])
Harden.extend([4])
Curry.extend([2])

# %% [markdown]
# ### Steals - Eastern Conference

# %%
Stealsplot(PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Eric Bledsoe - 5 points
# #### 2. Kemba Walker - 4 points
# #### 3. Dennis Schroder - 3 points
# #### 4. Kyrie Irving - 2 point
# #### 5. Goran Dragic - 1 point

# %%
Walker.extend([4])
Dragic.extend([1])
Bledsoe.extend([5])
Schroder.extend([3])
Irving.extend([2])

# %% [markdown]
# __________________________________________

# %% [markdown]
# ### Function for Manual Calculation

# %%
def Calculation(data, playerlist=Players):
    Col = {"DamianLillard":"Black", "DennisSchroder":"Red", "EricBledsoe":"Green", "GoranDragic":"Blue", "JamesHarden":"Cyan", "JrueHoliday":"Yellow", "KembaWalker":"Purple", "KyrieIrving":"Brown", "RussellWestbrook": "Orange", "StephenCurry":"Magenta"}
    Mrk = {"DamianLillard":"s","DennisSchroder":"o","EricBledsoe":"^","GoranDragic":"D","JamesHarden":"s","JrueHoliday":"o","KembaWalker":"^","KyrieIrving":"D","RussellWestbrook":"s","StephenCurry":"o"} 
    for name in playerlist:
        plt.plot(data[PlayerD[name]], c=Col[name], ls='--', marker=Mrk[name], ms=7, label=name)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,7)), Month)
    plt.show()

# %% [markdown]
# ### Shooting Accuracy - Western Conference

# %%
Calculation(FieldGoals/FieldGoalsAttempted, PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Stephen Curry - 5 points
# #### 2. Jrue Holiday - 4 points
# #### 3. James Harden - 3 points
# #### 4. Russell Westbrook - 2 points
# #### 5. Damian Lillard - 1 point

# %%
Holiday.extend([4])
Westbrook.extend([2])
Lillard.extend([1])
Harden.extend([3])
Curry.extend([5])

# %% [markdown]
# ### Shooting Accuracy - Eastern Conference

# %%
Calculation(FieldGoals/FieldGoalsAttempted, PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Kyrie Irving - 5 points
# #### 2. Goran Dragic - 4 points
# #### 3. Eric Bledsoe - 3 points
# #### 4. Dennis Schroder - 2 points
# #### 5. Kemba Walker - 1 point

# %%
Walker.extend([1])
Dragic.extend([4])
Bledsoe.extend([3])
Schroder.extend([2])
Irving.extend([5])

# %% [markdown]
# __________________________________________

# %% [markdown]
# ### Points/Minutes - Western Conference

# %%
Calculation(PointsMade/MinutesPlayed, PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Stephen Curry - 5 points
# #### 2. James Harden - 4 points
# #### 3. Damian Lillard - 3 points
# #### 4. Russell Westbrook - 2 points
# #### 5. Jrue Holiday - 1 point

# %%
Holiday.extend([1])
Westbrook.extend([2])
Lillard.extend([3])
Harden.extend([4])
Curry.extend([5])

# %% [markdown]
# ### Points/Minutes - Eastern Conference

# %%
Calculation(PointsMade/MinutesPlayed, PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Kyrie Irving - 5 points
# #### 2. Kemba Walker - 4 points
# #### 3. Dennis Schroder - 3 points
# #### 4. Eric Bledsoe - 2 points
# #### 5. Goran Dragic - 1 point

# %%
Walker.extend([4])
Dragic.extend([1])
Bledsoe.extend([2])
Schroder.extend([3])
Irving.extend([5])

# %% [markdown]
# __________________________________________________

# %% [markdown]
# ### Three Points Accuracy - Western Conference

# %%
Calculation(ThreePointsMade/ThreePointsAttempted, PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Stephen Curry -  5 points
# #### 2. James Harden - 4 points
# #### 3. Damian Lillard - 3 points
# #### 4. Jrue Holiday - 2 points
# #### 5. Russell Westbrook - 1 point

# %%
Holiday.extend([2])
Westbrook.extend([1])
Lillard.extend([3])
Harden.extend([4])
Curry.extend([5])

# %% [markdown]
# ### Three Points Accuracy - Eastern Conference

# %%
Calculation(ThreePointsMade/ThreePointsAttempted, PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Kyrie Irving -  5 points
# #### 2. Goran Dragic - 4 points
# #### 3. Kemba Walker - 3 points
# #### 4. Eric Bledsoe - 2 points
# #### 5. Dennis Schroder - 1 point

# %%
Walker.extend([3])
Dragic.extend([4])
Bledsoe.extend([2])
Schroder.extend([1])
Irving.extend([5])

# %% [markdown]
# _________________________________________________

# %% [markdown]
# ### Free Throw Accuracy - Western Conference

# %%
Calculation(FreeThrowMade/FreeThrowAttempted, PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Damian Lillard - 5 points
# #### 2. Stephen Curry - 4 points
# #### 3. James Harden - 3 points
# #### 4. Jrue Holiday - 2 points
# #### 5. Russell Westbrook - 1 point

# %%
Holiday.extend([2])
Westbrook.extend([1])
Lillard.extend([5])
Harden.extend([3])
Curry.extend([4])

# %% [markdown]
# ### Free Throw Accuracy - Eastern Conference

# %%
Calculation(FreeThrowMade/FreeThrowAttempted, PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Kyrie Irving - 5 points
# #### 2. Kemba Walker - 4 points
# #### 3. Dennis Schroder - 3 points
# #### 4. Goran Dragic - 2 points
# #### 5. Eric Bledsoe - 1 point

# %%
Walker.extend([4])
Dragic.extend([2])
Bledsoe.extend([1])
Schroder.extend([3])
Irving.extend([5])

# %% [markdown]
# ________________________________________________

# %% [markdown]
# __________________________________________________

# %% [markdown]
# ## Final Rankings - Western Conference

# %%
#Tallying up the points
Holiday_tally = sum(Holiday)
Westbrook_tally = sum(Westbrook)
Lillard_tally = sum(Lillard)
Harden_tally = sum(Harden)
Curry_tally = sum(Curry)

#X-Axis (Labels)
players_label = ['Jrue Holiday', 'Russell Westbrook', 'Damian Lillard', 'James Harden', 'Stephen Curry']
#Converting the X-Axis into an array
players_label_arr = np.array(players_label)

#Y-Axis (Values for the labels)
tally = [Holiday_tally, Westbrook_tally, Lillard_tally, Harden_tally, Curry_tally]

#Plotting the Bar
plt.bar(players_label_arr, tally)

#Labelling X and Y axes
plt.xlabel('Player Names', fontsize = 20, color='DarkBlue')
plt.ylabel('Total Points', fontsize = 20, color='DarkBlue')

#The Title
plt.title("WC Point Guard - Final Rankings", fontsize=35, color="DarkBlue", fontname="Console")

#Displaying the Bar
plt.show()

# %% [markdown]
# ### 1. James Harden
# ### 2. Russell Westbrook
# ### 3. Damian Lillard
# ### 4. Stephen Curry
# ### 5. Jrue Holiday

# %% [markdown]
# ## First Choice Point Guard (Western Conference): James Harden

# %% [markdown]
# ![James Harden](https://static1.i4u.com/sites/default/files/imagecache/main_image_google_topstories4x3/images/2015/08/jamesharden.jpg)

# %% [markdown]
# ## Reserve Point Guard (Western Conference): Russell Westbrook

# %% [markdown]
# ![Russell Westbrook](https://static1.i4u.com/sites/default/files/imagecache/main_image_google_topstories4x3/images/2015/04/russellwestbrook.jpg)

# %% [markdown]
# __________________________________________________

# %% [markdown]
# ## Final Rankings - Eastern Conference

# %%
#Tallying up the points
Irving_tally = sum(Irving)
Dragic_tally = sum(Dragic)
Walker_tally = sum(Walker)
Bledsoe_tally = sum(Bledsoe)
Schroder_tally = sum(Schroder)

#X-Axis (Labels)
players_label = ['Kyrie Irving', 'Goran Dragic', 'Kemba Walker', 'Eric Bledsoe', 'Dennis Schroder']
#Converting the X-Axis into an array
players_label_arr = np.array(players_label)

#Y-Axis (Values for the labels)
tally = [Irving_tally, Dragic_tally, Walker_tally, Bledsoe_tally, Schroder_tally]

#Plotting the Bar
plt.bar(players_label_arr, tally)

#Labelling X and Y axes
plt.xlabel('Player Names', fontsize = 20, color='DarkBlue')
plt.ylabel('Total Points', fontsize = 20, color='DarkBlue')

#The Title
plt.title("EC Point Guard - Final Rankings", fontsize=35, color="DarkBlue", fontname="Console")

#Displaying the Bar
plt.show()

# %% [markdown]
# ### 1. Kemba Walker
# ### 2. Kyrie Irving
# ### 3. Eric Bledsoe
# ### 4. Dennis Schroder
# ### 5. Goran Dragic

# %% [markdown]
# ## First Choice Point Guard (Eastern Conference): Kemba Walker

# %% [markdown]
# ![Kemba Walker](http://mediadb.kicker.de/news/1000/1020/36000/artikel02/1020092/walker-1521793405_zoom31_crop_800x600_800x600+8+69.jpg)

# %% [markdown]
# ## Reserve Point Guard (Eastern Conference): Kyrie Irving

# %% [markdown]
# ![Kyrie Irving](https://thesportspost.com/wp-content/uploads/2017/07/the-obvious-kyrie-irving-trade-everyone-is-missing-800x600.jpg)
