# %% [markdown]
# # Power Forwards

# %% [markdown]
# ### Months Played (Regular Season - 17/18)

# %%
Month = ["October","November","December","January","February","March","April"]
MonthD = {"October":0,"November":1,"December":2,"January":3,"February":4,"March":5,"April":6}

# %% [markdown]
# ### Player List

# %%
Players = ["AaronGordon", "AnthonyDavis", "CarmeloAnthony", "DarioSaric", "DerrickFavors", "GiannisAntetokounmpo", "JuliusRandle", "KristapsPorzingis", "LaMarcusAldridge", "LauriMarkkanen"]
PlayerD = {"AaronGordon":0, "AnthonyDavis":1, "CarmeloAnthony":2, "DarioSaric":3, "DerrickFavors":4, "GiannisAntetokounmpo":5, "JuliusRandle":6, "KristapsPorzingis":7, "LaMarcusAldridge":8, "LauriMarkkanen":9}

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Importing the CSV File

# %%
power_forward = pd.read_csv('C:\\Users\\Sarad\\Desktop\\Project\\Power_Forward.csv')

# %%
power_forward
# Out:
#                    PLAYER TEAM  GP  MIN  PTS  FGM  FGA  FTM  FTA  REB  AST  \
# 0            Aaron Gordon  ORL   5  151  105   39   71   14   19   45   12
# 1            Aaron Gordon  ORL  15  506  266   91  184   51   66  122   31
# 2            Aaron Gordon  ORL  15  506  266   91  184   51   66  122   31
# 3            Aaron Gordon  ORL  11  393  190   74  209   27   43  103   24
# 4            Aaron Gordon  ORL   4  120   58   22   55    6   11   29   16
# 5            Aaron Gordon  ORL   9  303  170   62  147   28   40   79   24
# 6            Aaron Gordon  ORL   6  161   76   30   79    6   11   24   12
# 7           Anthony Davis  NOP   6  202  166   58  106   43   53   75   12
# 8           Anthony Davis  NOP  14  499  345  126  217   86  109  145   42
# 9           Anthony Davis  NOP  14  499  345  126  217   86  109  145   42
# 10          Anthony Davis  NOP  13  508  361  131  254   93  109  151   41
# ...

# %% [markdown]
# ### Games

# %%
AaronGordon_Games = list(power_forward['GP'][0:7])
AnthonyDavis_Games = list(power_forward['GP'][7:14])
CarmeloAnthony_Games = list(power_forward['GP'][14:21])
DarioSaric_Games = list(power_forward['GP'][21:28])
DerrickFavors_Games = list(power_forward['GP'][28:35])
GiannisAntetokounmpo_Games = list(power_forward['GP'][35:42])
JuliusRandle_Games = list(power_forward['GP'][42:49])
KristapsPorzingis_Games = list(power_forward['GP'][49:56])
LaMarcusAldridge_Games = list(power_forward['GP'][56:63])
LauriMarkkanen_Games = list(power_forward['GP'][63:71])

Games = np.array([AaronGordon_Games, AnthonyDavis_Games, CarmeloAnthony_Games, DarioSaric_Games, DerrickFavors_Games, GiannisAntetokounmpo_Games, JuliusRandle_Games, KristapsPorzingis_Games, LaMarcusAldridge_Games, LauriMarkkanen_Games])

# %%
Games
# Out:
# array([[ 5, 15, 15, 11,  4,  9,  6],
#        [ 6, 14, 14, 13, 11, 14,  6],
#        [ 7, 12, 12, 14, 10, 13,  5],
#        [14, 14, 12, 11, 16,  4,  7],
#        [ 7, 15, 15, 12, 11, 13,  6],
#        [ 7, 12, 12, 13, 12, 14,  4],
#        [ 7, 14, 14, 15, 10, 15,  7],
#        [ 6, 13, 13, 15,  3,  0,  0],
#        [ 7, 14, 14, 14,  7, 12,  6],
#        [ 0, 15, 15, 14,  8,  5,  8]], dtype=int64)

# %% [markdown]
# ### Minutes Played

# %%
AaronGordon_Minutes = list(power_forward['MIN'][0:7])
AnthonyDavis_Minutes = list(power_forward['MIN'][7:14])
CarmeloAnthony_Minutes = list(power_forward['MIN'][14:21])
DarioSaric_Minutes = list(power_forward['MIN'][21:28])
DerrickFavors_Minutes = list(power_forward['MIN'][28:35])
GiannisAntetokounmpo_Minutes = list(power_forward['MIN'][35:42])
JuliusRandle_Minutes = list(power_forward['MIN'][42:49])
KristapsPorzingis_Minutes = list(power_forward['MIN'][49:56])
LaMarcusAldridge_Minutes = list(power_forward['MIN'][56:63])
LauriMarkkanen_Minutes = list(power_forward['MIN'][63:71])

MinutesPlayed = np.array([AaronGordon_Minutes, AnthonyDavis_Minutes, CarmeloAnthony_Minutes, DarioSaric_Minutes, DerrickFavors_Minutes, GiannisAntetokounmpo_Minutes, JuliusRandle_Minutes, KristapsPorzingis_Minutes, LaMarcusAldridge_Minutes, LauriMarkkanen_Minutes])

# %%
MinutesPlayed
# Out:
# array([[151, 506, 506, 393, 120, 303, 161],
#        [202, 499, 499, 508, 416, 493, 216],
#        [233, 383, 383, 443, 309, 407, 153],
#        [425, 425, 361, 352, 444,  81, 168],
#        [193, 421, 421, 354, 315, 349, 170],
#        [262, 445, 445, 457, 441, 513, 127],
#        [134, 332, 332, 388, 319, 522, 175],
#        [204, 394, 394, 510,  79,   0,   0],
#        [238, 461, 461, 497, 212, 384, 210],
#        [  0, 452, 452, 445, 252, 120, 230]], dtype=int64)

# %% [markdown]
# ### Points

# %%
AaronGordon_Points = list(power_forward['PTS'][0:7])
AnthonyDavis_Points = list(power_forward['PTS'][7:14])
CarmeloAnthony_Points = list(power_forward['PTS'][14:21])
DarioSaric_Points = list(power_forward['PTS'][21:28])
DerrickFavors_Points = list(power_forward['PTS'][28:35])
GiannisAntetokounmpo_Points = list(power_forward['PTS'][35:42])
JuliusRandle_Points = list(power_forward['PTS'][42:49])
KristapsPorzingis_Points = list(power_forward['PTS'][49:56])
LaMarcusAldridge_Points = list(power_forward['PTS'][56:63])
LauriMarkkanen_Points = list(power_forward['PTS'][63:71])

PointsMade = np.array([AaronGordon_Points, AnthonyDavis_Points, CarmeloAnthony_Points, DarioSaric_Points, DerrickFavors_Points, GiannisAntetokounmpo_Points, JuliusRandle_Points, KristapsPorzingis_Points, LaMarcusAldridge_Points, LauriMarkkanen_Points])

# %%
PointsMade
# Out:
# array([[105, 266, 266, 190,  58, 170,  76],
#        [166, 345, 345, 361, 385, 393, 170],
#        [160, 214, 214, 253, 134, 173,  71],
#        [181, 181, 185, 188, 255,  36,  54],
#        [ 88, 199, 199, 139, 131, 151,  83],
#        [236, 318, 318, 351, 271, 385,  76],
#        [ 80, 182, 182, 230, 194, 335, 103],
#        [176, 314, 314, 305,  49,   0,   0],
#        [165, 320, 320, 328, 163, 313, 140],
#        [  0, 213, 213, 239,  95,  97, 120]], dtype=int64)

# %% [markdown]
# ### Field Goals

# %%
AaronGordon_FG = list(power_forward['FGM'][0:7])
AnthonyDavis_FG = list(power_forward['FGM'][7:14])
CarmeloAnthony_FG = list(power_forward['FGM'][14:21])
DarioSaric_FG = list(power_forward['FGM'][21:28])
DerrickFavors_FG = list(power_forward['FGM'][28:35])
GiannisAntetokounmpo_FG = list(power_forward['FGM'][35:42])
JuliusRandle_FG = list(power_forward['FGM'][42:49])
KristapsPorzingis_FG = list(power_forward['FGM'][49:56])
LaMarcusAldridge_FG = list(power_forward['FGM'][56:63])
LauriMarkkanen_FG = list(power_forward['FGM'][63:71])

FieldGoals = np.array([AaronGordon_FG, AnthonyDavis_FG, CarmeloAnthony_FG, DarioSaric_FG, DerrickFavors_FG, GiannisAntetokounmpo_FG, JuliusRandle_FG, KristapsPorzingis_FG, LaMarcusAldridge_FG, LauriMarkkanen_FG])

# %%
FieldGoals
# Out:
# array([[ 39,  91,  91,  74,  22,  62,  30],
#        [ 58, 126, 126, 131, 144, 155,  59],
#        [ 59,  74,  74,  96,  54,  64,  25],
#        [ 66,  66,  59,  65,  87,  15,  21],
#        [ 40,  80,  80,  60,  54,  65,  36],
#        [ 91, 119, 119, 121, 106, 140,  30],
#        [ 31,  70,  70,  86,  83, 121,  34],
#        [ 65, 106, 106, 109,  19,   0,   0],
#        [ 64, 125, 125, 132,  65, 123,  60],
#        [  0,  75,  75,  86,  39,  32,  44]], dtype=int64)

# %% [markdown]
# ### Field Goals Attempted

# %%
AaronGordon_FGA = list(power_forward['FGA'][0:7])
AnthonyDavis_FGA = list(power_forward['FGA'][7:14])
CarmeloAnthony_FGA = list(power_forward['FGA'][14:21])
DarioSaric_FGA = list(power_forward['FGA'][21:28])
DerrickFavors_FGA = list(power_forward['FGA'][28:35])
GiannisAntetokounmpo_FGA = list(power_forward['FGA'][35:42])
JuliusRandle_FGA = list(power_forward['FGA'][42:49])
KristapsPorzingis_FGA = list(power_forward['FGA'][49:56])
LaMarcusAldridge_FGA = list(power_forward['FGA'][56:63])
LauriMarkkanen_FGA = list(power_forward['FGA'][63:71])

FieldGoalsAttempted = np.array([AaronGordon_FGA, AnthonyDavis_FGA, CarmeloAnthony_FGA, DarioSaric_FGA, DerrickFavors_FGA, GiannisAntetokounmpo_FGA, JuliusRandle_FGA, KristapsPorzingis_FGA, LaMarcusAldridge_FGA, LauriMarkkanen_FGA])

# %%
FieldGoalsAttempted
# Out:
# array([[ 71, 184, 184, 209,  55, 147,  79],
#        [106, 217, 217, 254, 284, 290, 117],
#        [127, 191, 191, 224, 148, 165,  67],
#        [154, 154, 136, 139, 176,  38,  59],
#        [ 74, 140, 140, 112,  99, 103,  64],
#        [144, 240, 240, 220, 222, 259,  70],
#        [ 49, 133, 133, 158, 141, 213,  69],
#        [136, 230, 230, 262,  40,   0,   0],
#        [129, 234, 234, 267, 113, 229, 113],
#        [  0, 196, 196, 180, 100,  63,  96]], dtype=int64)

# %% [markdown]
# ### Rebounds

# %%
AaronGordon_Rebound = list(power_forward['REB'][0:7])
AnthonyDavis_Rebound = list(power_forward['REB'][7:14])
CarmeloAnthony_Rebound = list(power_forward['REB'][14:21])
DarioSaric_Rebound = list(power_forward['REB'][21:28])
DerrickFavors_Rebound = list(power_forward['REB'][28:35])
GiannisAntetokounmpo_Rebound = list(power_forward['REB'][35:42])
JuliusRandle_Rebound = list(power_forward['REB'][42:49])
KristapsPorzingis_Rebound = list(power_forward['REB'][49:56])
LaMarcusAldridge_Rebound = list(power_forward['REB'][56:63])
LauriMarkkanen_Rebound = list(power_forward['REB'][63:71])

Rebounds = np.array([AaronGordon_Rebound, AnthonyDavis_Rebound, CarmeloAnthony_Rebound, DarioSaric_Rebound, DerrickFavors_Rebound, GiannisAntetokounmpo_Rebound, JuliusRandle_Rebound, KristapsPorzingis_Rebound, LaMarcusAldridge_Rebound, LauriMarkkanen_Rebound])

# %%
Rebounds
# Out:
# array([[ 45, 122, 122, 103,  29,  79,  24],
#        [ 75, 145, 145, 151, 143, 154,  67],
#        [ 31,  87,  87,  82,  58,  70,  28],
#        [104, 104,  82,  77, 104,  13,  30],
#        [ 36, 108, 108, 106,  90,  83,  42],
#        [ 72, 120, 120, 132, 118, 128,  43],
#        [ 37, 102, 102, 135,  90, 148,  51],
#        [ 50,  79,  79,  99,  17,   0,   0],
#        [ 59, 113, 113, 122,  45, 108,  59],
#        [  0, 116, 116, 118,  57,  32,  56]], dtype=int64)

# %% [markdown]
# ### Assists

# %%
AaronGordon_Assist = list(power_forward['AST'][0:7])
AnthonyDavis_Assist = list(power_forward['AST'][7:14])
CarmeloAnthony_Assist = list(power_forward['AST'][14:21])
DarioSaric_Assist = list(power_forward['AST'][21:28])
DerrickFavors_Assist = list(power_forward['AST'][28:35])
GiannisAntetokounmpo_Assist = list(power_forward['AST'][35:42])
JuliusRandle_Assist = list(power_forward['AST'][42:49])
KristapsPorzingis_Assist = list(power_forward['AST'][49:56])
LaMarcusAldridge_Assist = list(power_forward['AST'][56:63])
LauriMarkkanen_Assist = list(power_forward['AST'][63:71])

Assists = np.array([AaronGordon_Assist, AnthonyDavis_Assist, CarmeloAnthony_Assist, DarioSaric_Assist, DerrickFavors_Assist, GiannisAntetokounmpo_Assist, JuliusRandle_Assist, KristapsPorzingis_Assist, LaMarcusAldridge_Assist, LauriMarkkanen_Assist])

# %%
Assists
# Out:
# array([[12, 31, 31, 24, 16, 24, 12],
#        [12, 42, 42, 41, 17, 28, 15],
#        [11, 19, 19, 17,  5, 16,  8],
#        [27, 27, 31, 31, 38,  9, 11],
#        [14, 24, 24, 15,  9, 21,  5],
#        [37, 48, 48, 66, 64, 62, 22],
#        [12, 24, 24, 38, 43, 39, 24],
#        [ 5, 16, 16, 19,  0,  0,  0],
#        [13, 35, 35, 24, 20, 26, 10],
#        [ 0, 27, 27, 21,  3,  6,  7]], dtype=int64)

# %% [markdown]
# ### Blocks

# %%
AaronGordon_Block = list(power_forward['BLK'][0:7])
AnthonyDavis_Block = list(power_forward['BLK'][7:14])
CarmeloAnthony_Block = list(power_forward['BLK'][14:21])
DarioSaric_Block = list(power_forward['BLK'][21:28])
DerrickFavors_Block = list(power_forward['BLK'][28:35])
GiannisAntetokounmpo_Block = list(power_forward['BLK'][35:42])
JuliusRandle_Block = list(power_forward['BLK'][42:49])
KristapsPorzingis_Block = list(power_forward['BLK'][49:56])
LaMarcusAldridge_Block = list(power_forward['BLK'][56:63])
LauriMarkkanen_Block = list(power_forward['BLK'][63:71])

Block = np.array([AaronGordon_Block, AnthonyDavis_Block, CarmeloAnthony_Block, DarioSaric_Block, DerrickFavors_Block, GiannisAntetokounmpo_Block, JuliusRandle_Block, KristapsPorzingis_Block, LaMarcusAldridge_Block, LauriMarkkanen_Block])

# %%
Block
# Out:
# array([[ 5, 13, 13,  2,  6,  8,  4],
#        [12, 23, 23, 30, 24, 52, 21],
#        [ 8,  6,  6, 10,  6, 10,  2],
#        [ 7,  7,  3,  1,  4,  0,  2],
#        [ 2, 20, 20, 16,  8, 19,  8],
#        [ 7, 27, 27, 14, 21, 25,  3],
#        [ 7, 11, 11,  4,  7,  6,  1],
#        [10, 30, 30, 38, 10,  0,  0],
#        [ 9, 18, 18, 18,  7, 15,  9],
#        [ 0,  9,  9, 11,  6,  2,  4]], dtype=int64)

# %% [markdown]
# ### Free Throws Made

# %%
AaronGordon_FTM = list(power_forward['FTM'][0:7])
AnthonyDavis_FTM = list(power_forward['FTM'][7:14])
CarmeloAnthony_FTM = list(power_forward['FTM'][14:21])
DarioSaric_FTM = list(power_forward['FTM'][21:28])
DerrickFavors_FTM = list(power_forward['FTM'][28:35])
GiannisAntetokounmpo_FTM = list(power_forward['FTM'][35:42])
JuliusRandle_FTM = list(power_forward['FTM'][42:49])
KristapsPorzingis_FTM = list(power_forward['FTM'][49:56])
LaMarcusAldridge_FTM = list(power_forward['FTM'][56:63])
LauriMarkkanen_FTM = list(power_forward['FTM'][63:71])

FreeThrowMade = np.array([AaronGordon_FTM, AnthonyDavis_FTM, CarmeloAnthony_FTM, DarioSaric_FTM, DerrickFavors_FTM, GiannisAntetokounmpo_FTM, JuliusRandle_FTM, KristapsPorzingis_FTM, LaMarcusAldridge_FTM, LauriMarkkanen_FTM])

# %%
FreeThrowMade
# Out:
# array([[ 14,  51,  51,  27,   6,  28,   6],
#        [ 43,  86,  86,  93,  84,  72,  49],
#        [ 25,  37,  37,  30,   6,  12,  12],
#        [ 25,  25,  44,  32,  42,   1,   3],
#        [  7,  36,  36,  19,  21,  16,   9],
#        [ 48,  77,  77, 101,  53,  92,  15],
#        [ 17,  39,  39,  57,  27,  92,  35],
#        [ 34,  77,  77,  55,   7,   0,   0],
#        [ 33,  62,  62,  59,  32,  65,  20],
#        [  0,  30,  30,  29,  11,  15,  20]], dtype=int64)

# %% [markdown]
# ### Free Throws Attempted

# %%
AaronGordon_FTA = list(power_forward['FTA'][0:7])
AnthonyDavis_FTA = list(power_forward['FTA'][7:14])
CarmeloAnthony_FTA = list(power_forward['FTA'][14:21])
DarioSaric_FTA = list(power_forward['FTA'][21:28])
DerrickFavors_FTA = list(power_forward['FTA'][28:35])
GiannisAntetokounmpo_FTA = list(power_forward['FTA'][35:42])
JuliusRandle_FTA = list(power_forward['FTA'][42:49])
KristapsPorzingis_FTA = list(power_forward['FTA'][49:56])
LaMarcusAldridge_FTA = list(power_forward['FTA'][56:63])
LauriMarkkanen_FTA = list(power_forward['FTA'][63:71])

FreeThrowAttempted = np.array([AaronGordon_FTA, AnthonyDavis_FTA, CarmeloAnthony_FTA, DarioSaric_FTA, DerrickFavors_FTA, GiannisAntetokounmpo_FTA, JuliusRandle_FTA, KristapsPorzingis_FTA, LaMarcusAldridge_FTA, LauriMarkkanen_FTA])

# %%
FreeThrowAttempted
# Out:
# array([[ 19,  66,  66,  43,  11,  40,  11],
#        [ 53, 109, 109, 109, 101,  80,  64],
#        [ 31,  46,  46,  38,   8,  17,  15],
#        [ 30,  30,  46,  37,  52,   3,   5],
#        [ 12,  46,  46,  32,  33,  34,  14],
#        [ 62, 103, 103, 134,  78, 119,  19],
#        [ 26,  57,  57,  69,  44, 121,  44],
#        [ 42,  90,  90,  75,  13,   0,   0],
#        [ 42,  72,  72,  71,  39,  80,  22],
#        [  0,  37,  37,  32,  13,  21,  22]], dtype=int64)

# %% [markdown]
# ________________________________________________________

# %% [markdown]
# ## Vizualization

# %%
#Importing Numpy
import numpy as np
#Importing Matplotlib
import matplotlib.pyplot as plt
#Display Vizualization in the same page
# %matplotlib inline
#Increase the size of the graph
plt.rcParams['figure.figsize'] = 15,7
#Ignoring the Warnings
import warnings
warnings.filterwarnings('ignore')
#To remove the line - <matplotlib.lines.Line2D at 0x1978bdccc88>
plt.show()

# %% [markdown]
# ### Example

# %%
plt.plot(Games[0], c='Black', ls='--', marker='s', ms=7, label=Players[0])
plt.plot(Games[1], c='Red', ls='--', marker='o', ms=7, label=Players[1])
plt.plot(Games[2], c='Green', ls='--', marker='^', ms=7, label=Players[2])
plt.plot(Games[3], c='Blue', ls='--', marker='D', ms=7, label=Players[3])
plt.plot(Games[4], c='Magenta', ls='--', marker='s', ms=7, label=Players[4])
plt.plot(Games[5], c='Black', ls='--', marker='o', ms=7, label=Players[5])
plt.plot(Games[6], c='Red', ls='--', marker='^', ms=7, label=Players[6])
plt.plot(Games[7], c='Green', ls='--', marker='D', ms=7, label=Players[7])
plt.plot(Games[8], c='Blue', ls='--', marker='s', ms=7, label=Players[8])
plt.plot(Games[9], c='Magenta', ls='--', marker='o', ms=7, label=Players[9])
plt.xticks(list(range(0,7)), Month)
plt.legend(loc='upper left', bbox_to_anchor=(1,1))
plt.show()

# %% [markdown]
# ### Tally - Western Conference

# %%
Davis = []
Anthony = []
Favors = []
Randle = []
Aldridge = []

# %% [markdown]
# ### Tally - Eastern Conference

# %%
Gordon = []
Saric = []
Antetokounmpo = []
Porzingis = []
Markkanen = []

# %% [markdown]
# ### List for Players from from Western and Eastern Conference

# %%
PlayerWC = ["AnthonyDavis", "CarmeloAnthony", "DerrickFavors", "JuliusRandle", "LaMarcusAldridge"]
PlayerEC = ["AaronGordon", "DarioSaric", "GiannisAntetokounmpo", "KristapsPorzingis", "LauriMarkkanen"]

# %% [markdown]
# ### Function for Minutes Played

# %%
def Minutesplot(playerlist):
    Col = {"AnthonyDavis":"Black", "CarmeloAnthony":"Red", "DerrickFavors":"Green", "JuliusRandle":"Blue", "LaMarcusAldridge":"Cyan", "AaronGordon":"Yellow", "DarioSaric":"Purple", "GiannisAntetokounmpo":"Brown", "KristapsPorzingis": "Orange", "LauriMarkkanen":"Magenta"}
    Mrk = {"AnthonyDavis":"s","CarmeloAnthony":"o","DerrickFavors":"^","JuliusRandle":"D","LaMarcusAldridge":"s","AaronGordon":"o","DarioSaric":"^","GiannisAntetokounmpo":"D","KristapsPorzingis":"s","LauriMarkkanen":"o"} 
    for name in playerlist:
        plt.plot(MinutesPlayed[PlayerD[name]], c=Col[name], ls='--', marker=Mrk[name], ms=7, label=name)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,7)), Month)
    plt.show()

# %% [markdown]
# ### Minutes Played - Western Conference

# %%
Minutesplot(PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Anthony Davis - 5 points
# #### 2. LaMarcus Aldridge - 4 points
# #### 3. Carmelo Anthony - 3 points
# #### 4. Derrick Favors - 2 points
# #### 5. Julius Randle - 1 point

# %%
Davis.extend([5])
Aldridge.extend([4])
Anthony.extend([3])
Favors.extend([2])
Randle.extend([1])

# %% [markdown]
# ### Minutes Played - Eastern Conference

# %%
Minutesplot(PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Giannis Antetokounmpo - 5 points
# #### 2. Dario Saric - 4 points
# #### 3. Aaron Gordon - 3 points
# #### 4. Lauri Markkanen - 2 points
# #### 5. Kristaps Porzingis - 1 point

# %%
Antetokounmpo.extend([5])
Saric.extend([4])
Gordon.extend([3])
Markkanen.extend([2])
Porzingis.extend([1])

# %% [markdown]
# ______________________________________________________

# %% [markdown]
# ### Function for Points Scored

# %%
def Pointsplot(playerlist):
    Col = {"AnthonyDavis":"Black", "CarmeloAnthony":"Red", "DerrickFavors":"Green", "JuliusRandle":"Blue", "LaMarcusAldridge":"Cyan", "AaronGordon":"Yellow", "DarioSaric":"Purple", "GiannisAntetokounmpo":"Brown", "KristapsPorzingis": "Orange", "LauriMarkkanen":"Magenta"}
    Mrk = {"AnthonyDavis":"s","CarmeloAnthony":"o","DerrickFavors":"^","JuliusRandle":"D","LaMarcusAldridge":"s","AaronGordon":"o","DarioSaric":"^","GiannisAntetokounmpo":"D","KristapsPorzingis":"s","LauriMarkkanen":"o"} 
    for name in playerlist:
        plt.plot(PointsMade[PlayerD[name]], c=Col[name], ls='--', marker=Mrk[name], ms=7, label=name)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,7)), Month)
    plt.show()

# %% [markdown]
# ### Points Scored - Western Conference

# %%
Pointsplot(PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Anthony Davis - 5 points
# #### 2. LaMarcus Aldridge - 4 points
# #### 3. Julius Randle - 3 points
# #### 4. Carmelo Anthony - 2 points
# #### 5. Derrick Favors - 1 point

# %%
Davis.extend([5])
Aldridge.extend([4])
Anthony.extend([2])
Favors.extend([1])
Randle.extend([3])

# %% [markdown]
# ### Points Scored - Eastern Conference

# %%
Pointsplot(PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Giannis Antetokounmpo - 5 points
# #### 2. Kristaps Porzingis - 4 points
# #### 3. Aaron Gordon - 3 points
# #### 4. Dario Saric - 2 points
# #### 5. Lauri Markkanen - 1 point

# %%
Antetokounmpo.extend([5])
Saric.extend([2])
Gordon.extend([3])
Markkanen.extend([1])
Porzingis.extend([4])

# %% [markdown]
# _______________________________________________

# %% [markdown]
# ### Function for Field Goals

# %%
def FieldGoalsplot(playerlist):
    Col = {"AnthonyDavis":"Black", "CarmeloAnthony":"Red", "DerrickFavors":"Green", "JuliusRandle":"Blue", "LaMarcusAldridge":"Cyan", "AaronGordon":"Yellow", "DarioSaric":"Purple", "GiannisAntetokounmpo":"Brown", "KristapsPorzingis": "Orange", "LauriMarkkanen":"Magenta"}
    Mrk = {"AnthonyDavis":"s","CarmeloAnthony":"o","DerrickFavors":"^","JuliusRandle":"D","LaMarcusAldridge":"s","AaronGordon":"o","DarioSaric":"^","GiannisAntetokounmpo":"D","KristapsPorzingis":"s","LauriMarkkanen":"o"} 
    for name in playerlist:
        plt.plot(FieldGoals[PlayerD[name]], c=Col[name], ls='--', marker=Mrk[name], ms=7, label=name)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,7)), Month)
    plt.show()

# %% [markdown]
# ### Field Goals - Western Conference

# %%
FieldGoalsplot(PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Anthony Davis - 5 points
# #### 2. LaMarcus Aldridge - 4 points
# #### 3. Julius Randle - 3 points
# #### 4. Carmelo Anthony - 2 points
# #### 5. Derrick Favors - 1 point

# %%
Davis.extend([5])
Aldridge.extend([4])
Anthony.extend([2])
Favors.extend([1])
Randle.extend([3])

# %% [markdown]
# ### Field Goals - Eastern Conference

# %%
FieldGoalsplot(PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Giannis Antetokounmpo - 5 points
# #### 2. Aaron Gordon - 4 points
# #### 3. Kristaps Porzingis - 3 points
# #### 4. Dario Saric - 2 points
# #### 5. Lauri Markkanen - 1 point

# %%
Antetokounmpo.extend([5])
Saric.extend([2])
Gordon.extend([4])
Markkanen.extend([1])
Porzingis.extend([3])

# %% [markdown]
# _________________________________________________

# %% [markdown]
# ### Function for Rebounds

# %%
def Reboundsplot(playerlist):
    Col = {"AnthonyDavis":"Black", "CarmeloAnthony":"Red", "DerrickFavors":"Green", "JuliusRandle":"Blue", "LaMarcusAldridge":"Cyan", "AaronGordon":"Yellow", "DarioSaric":"Purple", "GiannisAntetokounmpo":"Brown", "KristapsPorzingis": "Orange", "LauriMarkkanen":"Magenta"}
    Mrk = {"AnthonyDavis":"s","CarmeloAnthony":"o","DerrickFavors":"^","JuliusRandle":"D","LaMarcusAldridge":"s","AaronGordon":"o","DarioSaric":"^","GiannisAntetokounmpo":"D","KristapsPorzingis":"s","LauriMarkkanen":"o"} 
    for name in playerlist:
        plt.plot(Rebounds[PlayerD[name]], c=Col[name], ls='--', marker=Mrk[name], ms=7, label=name)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,7)), Month)
    plt.show()

# %% [markdown]
# ### Rebound - Western Conference

# %%
Reboundsplot(PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Anthony Davis - 5 points
# #### 2. Julius Randle - 4 points
# #### 3. LaMarcus Aldridge - 3 points
# #### 4. Derrick Favors - 2 points
# #### 5. Carmelo Anthony - 1 point

# %%
Davis.extend([5])
Aldridge.extend([3])
Anthony.extend([1])
Favors.extend([2])
Randle.extend([4])

# %% [markdown]
# ### Rebound - Eastern Conference

# %%
Reboundsplot(PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Giannis Antetokounmpo - 5 points
# #### 2. Aaron Gordon - 4 points
# #### 3. Dario Saric - 3 points
# #### 4. Kristaps Porzingis - 2 points
# #### 5. Lauri Markkanen - 1 point

# %%
Antetokounmpo.extend([5])
Saric.extend([3])
Gordon.extend([4])
Markkanen.extend([2])
Porzingis.extend([1])

# %% [markdown]
# _____________________________

# %% [markdown]
# ### Function for Assists

# %%
def Assistsplot(playerlist):
    Col = {"AnthonyDavis":"Black", "CarmeloAnthony":"Red", "DerrickFavors":"Green", "JuliusRandle":"Blue", "LaMarcusAldridge":"Cyan", "AaronGordon":"Yellow", "DarioSaric":"Purple", "GiannisAntetokounmpo":"Brown", "KristapsPorzingis": "Orange", "LauriMarkkanen":"Magenta"}
    Mrk = {"AnthonyDavis":"s","CarmeloAnthony":"o","DerrickFavors":"^","JuliusRandle":"D","LaMarcusAldridge":"s","AaronGordon":"o","DarioSaric":"^","GiannisAntetokounmpo":"D","KristapsPorzingis":"s","LauriMarkkanen":"o"} 
    for name in playerlist:
        plt.plot(Assists[PlayerD[name]], c=Col[name], ls='--', marker=Mrk[name], ms=7, label=name)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,7)), Month)
    plt.show()

# %% [markdown]
# ### Assists - Western Conference

# %%
Assistsplot(PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Julius Randle - 5 points
# #### 2. Anthony Davis - 4 points
# #### 3. LaMarcus Aldridge - 3 points
# #### 4. Derrick Favors - 2 points
# #### 5. Carmelo Anthony - 1 point

# %%
Davis.extend([4])
Aldridge.extend([3])
Anthony.extend([1])
Favors.extend([2])
Randle.extend([5])

# %% [markdown]
# ### Assists - Eastern Conference

# %%
Assistsplot(PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Giannis Antetokounmpo - 5 points
# #### 2. Dario Saric - 4 points
# #### 3. Aaron Gordon - 3 points
# #### 4. Lauri Markkanen - 2 points
# #### 5. Kristaps Porzingis - 1 point

# %%
Antetokounmpo.extend([5])
Saric.extend([4])
Gordon.extend([3])
Markkanen.extend([2])
Porzingis.extend([1])

# %% [markdown]
# _____________________________________________

# %% [markdown]
# ### Function for Blocks

# %%
def Blocksplot(playerlist):
    Col = {"AnthonyDavis":"Black", "CarmeloAnthony":"Red", "DerrickFavors":"Green", "JuliusRandle":"Blue", "LaMarcusAldridge":"Cyan", "AaronGordon":"Yellow", "DarioSaric":"Purple", "GiannisAntetokounmpo":"Brown", "KristapsPorzingis": "Orange", "LauriMarkkanen":"Magenta"}
    Mrk = {"AnthonyDavis":"s","CarmeloAnthony":"o","DerrickFavors":"^","JuliusRandle":"D","LaMarcusAldridge":"s","AaronGordon":"o","DarioSaric":"^","GiannisAntetokounmpo":"D","KristapsPorzingis":"s","LauriMarkkanen":"o"} 
    for name in playerlist:
        plt.plot(Block[PlayerD[name]], c=Col[name], ls='--', marker=Mrk[name], ms=7, label=name)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,7)), Month)
    plt.show()

# %% [markdown]
# ### Blocks - Western Conference

# %%
Assistsplot(PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Anthony Davis - 5 points
# #### 2. LaMarcus Aldridge - 4 points
# #### 3. Derrick Favors - 3 points
# #### 4. Carmelo Anthony - 2 points
# #### 5. Julius Randle - 1 point

# %%
Davis.extend([5])
Aldridge.extend([4])
Anthony.extend([2])
Favors.extend([3])
Randle.extend([1])

# %% [markdown]
# ### Blocks - Eastern Conference

# %%
Assistsplot(PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Giannis Antetokounmpo - 5 points
# #### 2. Kristaps Porzingis - 4 points
# #### 3. Aaron Gordon - 3 points
# #### 4. Lauri Markkanen - 2 points
# #### 5. Dario Saric - 1 point

# %%
Antetokounmpo.extend([5])
Saric.extend([1])
Gordon.extend([3])
Markkanen.extend([2])
Porzingis.extend([4])

# %% [markdown]
# ________________________________________________

# %% [markdown]
# ### Function for Free Throws Made

# %%
def FreeThrowsplot(playerlist):
    Col = {"AnthonyDavis":"Black", "CarmeloAnthony":"Red", "DerrickFavors":"Green", "JuliusRandle":"Blue", "LaMarcusAldridge":"Cyan", "AaronGordon":"Yellow", "DarioSaric":"Purple", "GiannisAntetokounmpo":"Brown", "KristapsPorzingis": "Orange", "LauriMarkkanen":"Magenta"}
    Mrk = {"AnthonyDavis":"s","CarmeloAnthony":"o","DerrickFavors":"^","JuliusRandle":"D","LaMarcusAldridge":"s","AaronGordon":"o","DarioSaric":"^","GiannisAntetokounmpo":"D","KristapsPorzingis":"s","LauriMarkkanen":"o"} 
    for name in playerlist:
        plt.plot(FreeThrowMade[PlayerD[name]], c=Col[name], ls='--', marker=Mrk[name], ms=7, label=name)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,7)), Month)
    plt.show()

# %% [markdown]
# ### Free Throws Made - Western Conference

# %%
FreeThrowsplot(PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Anthony Davis - 5 points
# #### 2. LaMarcus Aldridge - 4 points
# #### 3. Julius Randle - 3 points
# #### 4. Carmelo Anthony - 2 points
# #### 5. Derrick Favors - 1 point

# %%
Davis.extend([5])
Aldridge.extend([4])
Anthony.extend([2])
Favors.extend([1])
Randle.extend([3])

# %% [markdown]
# ### Free Throws Made - Eastern Conference

# %%
FreeThrowsplot(PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Giannis Antetokounmpo - 5 points
# #### 2. Kristaps Porzingis - 4 points
# #### 3. Aaron Gordon - 3 points
# #### 4. Daric Saric - 2 points
# #### 5. Lauri Markkanen - 1 point

# %%
Antetokounmpo.extend([5])
Saric.extend([2])
Gordon.extend([3])
Markkanen.extend([1])
Porzingis.extend([4])

# %% [markdown]
# ______________________________________________

# %% [markdown]
# ### Function Manual Calculations

# %%
def Calculation(data, playerlist=Players):
    Col = {"AnthonyDavis":"Black", "CarmeloAnthony":"Red", "DerrickFavors":"Green", "JuliusRandle":"Blue", "LaMarcusAldridge":"Cyan", "AaronGordon":"Yellow", "DarioSaric":"Purple", "GiannisAntetokounmpo":"Brown", "KristapsPorzingis": "Orange", "LauriMarkkanen":"Magenta"}
    Mrk = {"AnthonyDavis":"s","CarmeloAnthony":"o","DerrickFavors":"^","JuliusRandle":"D","LaMarcusAldridge":"s","AaronGordon":"o","DarioSaric":"^","GiannisAntetokounmpo":"D","KristapsPorzingis":"s","LauriMarkkanen":"o"} 
    for name in playerlist:
        plt.plot(data[PlayerD[name]], c=Col[name], ls='--', marker=Mrk[name], ms=7, label=name)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,7)), Month)
    plt.show()

# %% [markdown]
# ### Shooting Accuracy - Western Conference

# %%
Calculation(FieldGoals/FieldGoalsAttempted, PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Derrick Favors - 5 points
# #### 2. Julius Randle - 4 points
# #### 3. Anthony Davis - 3 points
# #### 4. LaMarcus Aldridge - 2 points
# #### 5. Carmelo Anthony - 1 point

# %%
Davis.extend([3])
Aldridge.extend([2])
Anthony.extend([1])
Favors.extend([5])
Randle.extend([4])

# %% [markdown]
# ### Shooting Accuracy - Eastern Conference

# %%
Calculation(FieldGoals/FieldGoalsAttempted, PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Giannis Antetokounmpo - 5 points
# #### 2. Kristaps Porzingis - 4 points
# #### 3. Dario Saric - 3 points
# #### 4. Aaron Gordon - 2 points
# #### 5. Lauri Markkanen - 1 point

# %%
Antetokounmpo.extend([5])
Saric.extend([3])
Gordon.extend([2])
Markkanen.extend([1])
Porzingis.extend([4])

# %% [markdown]
# _____________________________________________

# %% [markdown]
# ### Points/Minutes - Western Conference

# %%
Calculation(PointsMade/MinutesPlayed, PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Anthony Davis - 5 points
# #### 2. LaMarcus Aldridge - 4 points
# #### 3. Julius Randle - 3 points
# #### 4. Carmelo Anthony - 2 points
# #### 5. Derrick Favors - 1 point

# %%
Davis.extend([5])
Aldridge.extend([4])
Anthony.extend([2])
Favors.extend([1])
Randle.extend([3])

# %% [markdown]
# ### Points/Minutes - Eastern Conference

# %%
Calculation(PointsMade/MinutesPlayed, PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Giannis Antetokounmpo - 5 points
# #### 2. Kristaps Porzingis - 4 points
# #### 3. Aaron Gordon - 3 points
# #### 4. Lauri Markkanen - 2 points
# #### 5. Dario Saric - 1 point

# %%
Antetokounmpo.extend([5])
Saric.extend([1])
Gordon.extend([3])
Markkanen.extend([2])
Porzingis.extend([4])

# %% [markdown]
# ________________________________________

# %% [markdown]
# ### Free Throw Accuracy - Western Conference

# %%
Calculation(FreeThrowMade/FreeThrowAttempted, PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Anthony Davis - 5 points
# #### 2. LaMarcus Aldridge - 4 points
# #### 3. Carmelo Anthony - 3 points
# #### 4. Julius Randle - 2 points
# #### 5. Derrick Favors - 1 point

# %%
Davis.extend([5])
Aldridge.extend([4])
Anthony.extend([3])
Favors.extend([1])
Randle.extend([2])

# %% [markdown]
# ### Free Throw Accuracy - Eastern Conference

# %%
Calculation(FreeThrowMade/FreeThrowAttempted, PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Lauri Markkanen - 5 points
# #### 2. Giannis Antetokounmpo - 4 points
# #### 3. Dario Saric - 3 points
# #### 4. Kristaps Porzingis - 2 points
# #### 5. Aaron Gordon - 1 point

# %%
Antetokounmpo.extend([4])
Saric.extend([3])
Gordon.extend([1])
Markkanen.extend([5])
Porzingis.extend([2])

# %% [markdown]
# ____________________________________________________

# %% [markdown]
# ### Player Defensive Efficiency - Western Conference

# %%
Calculation((Block + Rebounds)/MinutesPlayed, PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Anthony Davis - 5 points
# #### 2. Julius Randle - 4 points
# #### 3. LaMarcus Aldridge - 3 points
# #### 4. Derrick Favors - 2 points
# #### 5. Carmelo Anthony - 1 point

# %%
Davis.extend([5])
Aldridge.extend([3])
Anthony.extend([1])
Favors.extend([2])
Randle.extend([4])

# %% [markdown]
# ### Player Defensive Efficiency - Eastern Conference

# %%
Calculation((Block + Rebounds)/MinutesPlayed, PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Giannis Antetokounmpo - 5 points
# #### 2. Aaron Gordon - 4 points
# #### 3. Lauri Markkanen - 3 points
# #### 4. Kristaps Porzingis - 2 points
# #### 5. Dario Saric - 1 point

# %%
Antetokounmpo.extend([5])
Saric.extend([1])
Gordon.extend([4])
Markkanen.extend([3])
Porzingis.extend([2])

# %% [markdown]
# _________________________________________________

# %% [markdown]
# _________________________________________________

# %% [markdown]
# ## Final Rankings - Western Conference

# %%
#Tallying up the points
Davis_tally = sum(Davis)
Aldridge_tally = sum(Aldridge)
Anthony_tally = sum(Anthony)
Favors_tally = sum(Favors)
Randle_tally = sum(Randle)

#X-Axis (Labels)
players_label = ['Anthony Davis', 'LaMarcus Aldridge', 'Carmelo Anthony', 'Derrick Favors', 'Julius Randle']
#Converting the X-Axis into an array
players_label_arr = np.array(players_label)

#Y-Axis (Values for the labels)
tally = [Davis_tally, Aldridge_tally, Anthony_tally, Favors_tally, Randle_tally]

#Plotting the Bar
plt.bar(players_label_arr, tally)

#Labelling X and Y axes
plt.xlabel('Player Names', fontsize = 20, color='DarkBlue')
plt.ylabel('Total Points', fontsize = 20, color='DarkBlue')

#The Title
plt.title("WC Power Forward - Final Rankings", fontsize=35, color="DarkBlue", fontname="Console")

#Displaying the Bar
plt.show()

# %% [markdown]
# ### 1. Anthony Davis
# ### 2. LaMarcus Aldridge
# ### 3. Julius Randle
# ### 4. Derrick Favors
# ### 5. Carmelo Anthony

# %% [markdown]
# ## First Choice Power Forward (Western Conference): Anthony Davis

# %% [markdown]
# ![Anthony Davis](https://s.yimg.com/ny/api/res/1.2/6GHdLibVPqfXtcpfIrUjEQ--/YXBwaWQ9aGlnaGxhbmRlcjtzbT0xO3c9ODAw/http://globalfinance.zenfs.com/en_us/Finance/US_AFTP_SILICONALLEY_H_LIVE/Anthony_Davis_Fixed_His_Biggest-754325f28e2c27c13712185dc2f8357c)

# %% [markdown]
# ## Reserve Power Forward (Eastern Conference): LaMarcus Aldridge

# %% [markdown]
# ![LaMarcus Aldridge](http://mediadb.kicker.de/news/1000/1020/36000/artikel02/1020402/lma-1522220829.jpg)

# %% [markdown]
# ___________________________________________________________

# %% [markdown]
# ## Final Rankings - Eastern Conference

# %%
#Tallying up the points
Gordon_tally = sum(Gordon)
Saric_tally = sum(Saric)
Antetokounmpo_tally = sum(Antetokounmpo)
Porzingis_tally = sum(Porzingis)
Markkanen_tally = sum(Markkanen)

#X-Axis (Labels)
players_label = ['Aaron Gordon', 'Dario Saric', 'Giannis Antetokounmpo', 'Lauri Markkanen', 'Julius Randle']
#Converting the X-Axis into an array
players_label_arr = np.array(players_label)

#Y-Axis (Values for the labels)
tally = [Gordon_tally, Saric_tally, Antetokounmpo_tally, Porzingis_tally, Markkanen_tally]

#Plotting the Bar
plt.bar(players_label_arr, tally)

#Labelling X and Y axes
plt.xlabel('Player Names', fontsize = 20, color='DarkBlue')
plt.ylabel('Total Points', fontsize = 20, color='DarkBlue')

#The Title
plt.title("EC Power Forward - Final Rankings", fontsize=35, color="DarkBlue", fontname="Console")

#Displaying the Bar
plt.show()

# %% [markdown]
# ### 1. Giannis Antetokounmpo
# ### 2. Aaron Gordon
# ### 3. Lauri Markkanen
# ### 4. Dario Saric
# ### 5. Julius Randle

# %% [markdown]
# ## First Choice Power Forward (Eastern Conference) - Giannis Antetokounmpo

# %% [markdown]
# ![Giannis Antetokounmpo](https://onmilwaukee.com/images/articles/bu/bucks-giannis-media-day-jokes/bucks-giannis-media-day-jokes_fullsize_story1.jpg?1525259158)

# %% [markdown]
# ## Reserve Power Forward (Eastern Conference) - Aaron Gordon

# %% [markdown]
# ![Aaron Gordon](http://mediadb.kicker.de/news/1000/1020/36000/artikel02/1015536/gordon_theis-1516610322_zoom29_crop_800x600_800x600+47+10.jpg)
