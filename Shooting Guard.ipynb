# %% [markdown]
# # Shooting Guard

# %% [markdown]
# ### Months Played (Regular Season - 17/18)

# %%
Month = ["October","November","December","January","February","March","April"]
MonthD = {"October":0,"November":1,"December":2,"January":3,"February":4,"March":5,"April":6}

# %% [markdown]
# ### Player List

# %%
Players = ["BradleyBeal", "CJMcCollum", "DeMarDeRozan", "DevinBooker", "DonovanMitchell", "EvanFournier", "JimmyButler", "JJRedick", "LouWilliams", "VictorOladipo"]
PlayerD = {"BradleyBeal":0, "CJMcCollum":1, "DeMarDeRozan":2, "DevinBooker":3, "DonovanMitchell":4, "EvanFournier":5, "JimmyButler":6, "JJRedick":7, "LouWilliams":8, "VictorOladipo":9}

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Importing the CSV File

# %%
shooting_guard = pd.read_csv('C:\\Users\\Sarad\\Desktop\\Project\\Shooting_Guard.csv')

# %%
shooting_guard
# Out:
#               PLAYER TEAM  GP  MIN  PTS  FGM  FGA  3PM  3PA  FTM  FTA  REB  \
# 0       Bradley Beal  WAS   6  194  117   42   93    6   24   27   34   27
# 1       Bradley Beal  WAS  15  536  371  129  279   42  102   71   86   67
# 2       Bradley Beal  WAS  16  580  376  144  332   40  115   48   67   68
# 3       Bradley Beal  WAS  13  497  327  115  228   35   86   62   79   59
# 4       Bradley Beal  WAS  12  452  261  102  220   28   78   29   33   58
# 5       Bradley Beal  WAS  14  503  280  107  230   36   89   30   40   55
# 6       Bradley Beal  WAS   6  216  125   44  102   12   36   25   30   29
# 7        CJ McCollum  POR   6  211  139   50  105   16   28   23   27   27
# 8        CJ McCollum  POR  15  556  306  115  261   42   95   34   38   64
# 9        CJ McCollum  POR  13  479  270  105  247   20   68   40   46   48
# 10       CJ McCollum  POR  16  561  383  147  305   49  104   40   45   62
# ...

# %% [markdown]
# ### Games

# %%
BradleyBeal_Games = list(shooting_guard['GP'][0:7])
CJMcCollum_Games = list(shooting_guard['GP'][7:14])
DeMarDeRozan_Games = list(shooting_guard['GP'][14:21])
DevinBooker_Games = list(shooting_guard['GP'][21:28])
DonovanMitchell_Games = list(shooting_guard['GP'][28:35])
EvanFournier_Games = list(shooting_guard['GP'][35:42])
JimmyButler_Games = list(shooting_guard['GP'][42:49])
JJRedick_Games = list(shooting_guard['GP'][49:56])
LouWilliams_Games = list(shooting_guard['GP'][56:63])
VictorOladipo_Games = list(shooting_guard['GP'][63:71])

Games = np.array([BradleyBeal_Games, CJMcCollum_Games, DeMarDeRozan_Games, DevinBooker_Games, DonovanMitchell_Games, EvanFournier_Games, JimmyButler_Games, JJRedick_Games, LouWilliams_Games, VictorOladipo_Games])

# %%
Games
# Out:
# array([[ 6, 15, 16, 13, 12, 14,  6],
#        [ 6, 15, 13, 16, 10, 15,  6],
#        [ 6, 14, 14, 15, 11, 15,  5],
#        [ 7, 15,  6, 13,  7,  6,  0],
#        [ 7, 15, 13, 13, 10, 15,  6],
#        [ 7, 15,  7, 13, 11,  4,  0],
#        [ 5, 15, 15, 13,  8,  0,  0],
#        [ 5, 14, 13,  5, 11, 16,  6],
#        [ 6, 14, 14, 15, 10, 16,  4],
#        [ 7, 14, 12, 14,  8, 15,  5]], dtype=int64)

# %% [markdown]
# ### Minutes Played

# %%
BradleyBeal_Minutes = list(shooting_guard['MIN'][0:7])
CJMcCollum_Minutes = list(shooting_guard['MIN'][7:14])
DeMarDeRozan_Minutes = list(shooting_guard['MIN'][14:21])
DevinBooker_Minutes = list(shooting_guard['MIN'][21:28])
DonovanMitchell_Minutes = list(shooting_guard['MIN'][28:35])
EvanFournier_Minutes = list(shooting_guard['MIN'][35:42])
JimmyButler_Minutes = list(shooting_guard['MIN'][42:49])
JJRedick_Minutes = list(shooting_guard['MIN'][49:56])
LouWilliams_Minutes = list(shooting_guard['MIN'][56:63])
VictorOladipo_Minutes = list(shooting_guard['MIN'][63:71])

MinutesPlayed = np.array([BradleyBeal_Minutes, CJMcCollum_Minutes, DeMarDeRozan_Minutes, DevinBooker_Minutes, DonovanMitchell_Minutes, EvanFournier_Minutes, JimmyButler_Minutes, JJRedick_Minutes, LouWilliams_Minutes, VictorOladipo_Minutes])

# %%
MinutesPlayed
# Out:
# array([[194, 536, 580, 497, 452, 503, 216],
#        [211, 556, 479, 561, 354, 545, 218],
#        [207, 479, 482, 524, 350, 515, 155],
#        [230, 504, 223, 443, 257, 209,   0],
#        [155, 475, 445, 456, 346, 568, 194],
#        [232, 472, 240, 423, 352, 118,   0],
#        [191, 532, 583, 466, 305,   0,   0],
#        [162, 467, 429, 141, 317, 420, 180],
#        [134, 451, 474, 530, 329, 539, 131],
#        [216, 479, 441, 479, 272, 510, 155]], dtype=int64)

# %% [markdown]
# ### Points Made

# %%
BradleyBeal_Points = list(shooting_guard['PTS'][0:7])
CJMcCollum_Points = list(shooting_guard['PTS'][7:14])
DeMarDeRozan_Points = list(shooting_guard['PTS'][14:21])
DevinBooker_Points = list(shooting_guard['PTS'][21:28])
DonovanMitchell_Points = list(shooting_guard['PTS'][28:35])
EvanFournier_Points = list(shooting_guard['PTS'][35:42])
JimmyButler_Points = list(shooting_guard['PTS'][42:49])
JJRedick_Points = list(shooting_guard['PTS'][49:56])
LouWilliams_Points = list(shooting_guard['PTS'][56:63])
VictorOladipo_Points = list(shooting_guard['PTS'][63:71])

PointsMade = np.array([BradleyBeal_Points, CJMcCollum_Points, DeMarDeRozan_Points, DevinBooker_Points, DonovanMitchell_Points, EvanFournier_Points, JimmyButler_Points, JJRedick_Points, LouWilliams_Points, VictorOladipo_Points])

# %%
PointsMade
# Out:
# array([[117, 371, 376, 327, 261, 280, 125],
#        [139, 306, 270, 383, 199, 331, 104],
#        [142, 324, 353, 379, 227, 333,  82],
#        [155, 350, 193, 304, 195, 149,   0],
#        [ 65, 271, 300, 288, 214, 345, 133],
#        [154, 236, 141, 226, 197,  59,   0],
#        [ 81, 269, 397, 298, 198,   0,   0],
#        [ 66, 227, 253,  98, 152, 264, 138],
#        [ 79, 295, 353, 423, 218, 336,  78],
#        [167, 312, 342, 303, 201, 302, 108]], dtype=int64)

# %% [markdown]
# ### Field Goals

# %%
BradleyBeal_FG = list(shooting_guard['FGM'][0:7])
CJMcCollum_FG = list(shooting_guard['FGM'][7:14])
DeMarDeRozan_FG = list(shooting_guard['FGM'][14:21])
DevinBooker_FG = list(shooting_guard['FGM'][21:28])
DonovanMitchell_FG = list(shooting_guard['FGM'][28:35])
EvanFournier_FG = list(shooting_guard['FGM'][35:42])
JimmyButler_FG = list(shooting_guard['FGM'][42:49])
JJRedick_FG = list(shooting_guard['FGM'][49:56])
LouWilliams_FG = list(shooting_guard['FGM'][56:63])
VictorOladipo_FG = list(shooting_guard['FGM'][63:71])

FieldGoals = np.array([BradleyBeal_FG, CJMcCollum_FG, DeMarDeRozan_FG, DevinBooker_FG, DonovanMitchell_FG, EvanFournier_FG, JimmyButler_FG, JJRedick_FG, LouWilliams_FG, VictorOladipo_FG])

# %%
FieldGoals
# Out:
# array([[ 42, 129, 144, 115, 102, 107,  44],
#        [ 50, 115, 105, 147,  80, 129,  41],
#        [ 48, 120, 117, 135,  79, 116,  30],
#        [ 57, 119,  63,  94,  66,  56,   0],
#        [ 25,  99, 113, 107,  78, 124,  49],
#        [ 55,  87,  52,  81,  71,  22,   0],
#        [ 29,  96, 136,  91,  65,   0,   0],
#        [ 25,  80,  81,  28,  52,  89,  49],
#        [ 26,  99, 107, 135,  73, 118,  24],
#        [ 54, 119, 121, 116,  74, 112,  44]], dtype=int64)

# %% [markdown]
# ### Field Goals Attempted

# %%
BradleyBeal_FGA = list(shooting_guard['FGA'][0:7])
CJMcCollum_FGA = list(shooting_guard['FGA'][7:14])
DeMarDeRozan_FGA = list(shooting_guard['FGA'][14:21])
DevinBooker_FGA = list(shooting_guard['FGA'][21:28])
DonovanMitchell_FGA = list(shooting_guard['FGA'][28:35])
EvanFournier_FGA = list(shooting_guard['FGA'][35:42])
JimmyButler_FGA = list(shooting_guard['FGA'][42:49])
JJRedick_FGA = list(shooting_guard['FGA'][49:56])
LouWilliams_FGA = list(shooting_guard['FGA'][56:63])
VictorOladipo_FGA = list(shooting_guard['FGA'][63:71])

FieldGoalsAttempted = np.array([BradleyBeal_FGA, CJMcCollum_FGA, DeMarDeRozan_FGA, DevinBooker_FGA, DonovanMitchell_FGA, EvanFournier_FGA, JimmyButler_FGA, JJRedick_FGA, LouWilliams_FGA, VictorOladipo_FGA])

# %%
FieldGoalsAttempted
# Out:
# array([[ 93, 279, 332, 228, 220, 230, 102],
#        [105, 261, 247, 305, 195, 278, 114],
#        [100, 247, 247, 302, 184, 257,  76],
#        [126, 268, 144, 229, 163, 124,   0],
#        [ 76, 240, 223, 238, 189, 292, 104],
#        [101, 202, 101, 193, 153,  52,   0],
#        [ 66, 218, 269, 190, 139,   0,   0],
#        [ 59, 189, 176,  55, 129, 178,  93],
#        [ 61, 214, 247, 306, 164, 285,  60],
#        [110, 258, 238, 234, 169, 256,  77]], dtype=int64)

# %% [markdown]
# ### Rebounds

# %%
BradleyBeal_Rebound = list(shooting_guard['REB'][0:7])
CJMcCollum_Rebound = list(shooting_guard['REB'][7:14])
DeMarDeRozan_Rebound = list(shooting_guard['REB'][14:21])
DevinBooker_Rebound = list(shooting_guard['REB'][21:28])
DonovanMitchell_Rebound = list(shooting_guard['REB'][28:35])
EvanFournier_Rebound = list(shooting_guard['REB'][35:42])
JimmyButler_Rebound = list(shooting_guard['REB'][42:49])
JJRedick_Rebound = list(shooting_guard['REB'][49:56])
LouWilliams_Rebound = list(shooting_guard['REB'][56:63])
VictorOladipo_Rebound = list(shooting_guard['REB'][63:71])

Rebounds = np.array([BradleyBeal_Rebound, CJMcCollum_Rebound, DeMarDeRozan_Rebound, DevinBooker_Rebound, DonovanMitchell_Rebound, EvanFournier_Rebound, JimmyButler_Rebound, JJRedick_Rebound, LouWilliams_Rebound, VictorOladipo_Rebound])

# %%
Rebounds
# Out:
# array([[27, 67, 68, 59, 58, 55, 29],
#        [27, 64, 48, 62, 29, 64, 27],
#        [22, 64, 60, 55, 35, 59, 20],
#        [44, 52, 30, 55, 40, 23,  0],
#        [10, 58, 44, 49, 42, 61, 32],
#        [30, 43, 24, 36, 36, 11,  0],
#        [27, 82, 82, 68, 46,  0,  0],
#        [16, 40, 27, 18, 27, 36, 14],
#        [11, 42, 37, 33, 27, 43,  5],
#        [31, 73, 70, 69, 51, 74, 22]], dtype=int64)

# %% [markdown]
# ### Assist

# %%
BradleyBeal_Assist = list(shooting_guard['AST'][0:7])
CJMcCollum_Assist = list(shooting_guard['AST'][7:14])
DeMarDeRozan_Assist = list(shooting_guard['AST'][14:21])
DevinBooker_Assist = list(shooting_guard['AST'][21:28])
DonovanMitchell_Assist = list(shooting_guard['AST'][28:35])
EvanFournier_Assist = list(shooting_guard['AST'][35:42])
JimmyButler_Assist = list(shooting_guard['AST'][42:49])
JJRedick_Assist = list(shooting_guard['AST'][49:56])
LouWilliams_Assist = list(shooting_guard['AST'][56:63])
VictorOladipo_Assist = list(shooting_guard['AST'][63:71])

Assists = np.array([BradleyBeal_Assist, CJMcCollum_Assist, DeMarDeRozan_Assist, DevinBooker_Assist, DonovanMitchell_Assist, EvanFournier_Assist, JimmyButler_Assist, JJRedick_Assist, LouWilliams_Assist, VictorOladipo_Assist])

# %%
Assists
# Out:
# array([[18, 55, 59, 64, 80, 70, 27],
#        [16, 39, 44, 64, 25, 55, 29],
#        [27, 67, 71, 89, 57, 79, 27],
#        [30, 58, 29, 78, 33, 25,  0],
#        [17, 54, 49, 44, 38, 64, 25],
#        [27, 40, 21, 37, 28, 12,  0],
#        [22, 68, 79, 70, 40,  0,  0],
#        [16, 52, 39, 13, 36, 35, 19],
#        [23, 58, 81, 94, 61, 86, 14],
#        [21, 60, 48, 64, 39, 58, 33]], dtype=int64)

# %% [markdown]
# ### Free Throws Made

# %%
BradleyBeal_FTM = list(shooting_guard['FTM'][0:7])
CJMcCollum_FTM = list(shooting_guard['FTM'][7:14])
DeMarDeRozan_FTM = list(shooting_guard['FTM'][14:21])
DevinBooker_FTM = list(shooting_guard['FTM'][21:28])
DonovanMitchell_FTM = list(shooting_guard['FTM'][28:35])
EvanFournier_FTM = list(shooting_guard['FTM'][35:42])
JimmyButler_FTM = list(shooting_guard['FTM'][42:49])
JJRedick_FTM = list(shooting_guard['FTM'][49:56])
LouWilliams_FTM = list(shooting_guard['FTM'][56:63])
VictorOladipo_FTM = list(shooting_guard['FTM'][63:71])

FreeThrowMade = np.array([BradleyBeal_FTM, CJMcCollum_FTM, DeMarDeRozan_FTM, DevinBooker_FTM, DonovanMitchell_FTM, EvanFournier_FTM, JimmyButler_FTM, JJRedick_FTM, LouWilliams_FTM, VictorOladipo_FTM])

# %%
FreeThrowMade
# Out:
# array([[ 27,  71,  48,  62,  29,  30,  25],
#        [ 23,  34,  40,  40,  20,  38,  14],
#        [ 44,  70, 103,  88,  54,  85,  17],
#        [ 24,  76,  47,  81,  42,  19,   0],
#        [  7,  34,  45,  42,  29,  60,  22],
#        [ 24,  33,  20,  34,  31,   8,   0],
#        [ 19,  59, 107, 100,  55,   0,   0],
#        [  5,  30,  54,  26,  22,  43,  17],
#        [ 19,  59,  92, 104,  54,  78,  26],
#        [ 43,  41,  59,  47,  42,  53,   9]], dtype=int64)

# %% [markdown]
# ### Free Throws Attempted

# %%
BradleyBeal_FTA = list(shooting_guard['FTA'][0:7])
CJMcCollum_FTA = list(shooting_guard['FTA'][7:14])
DeMarDeRozan_FTA = list(shooting_guard['FTA'][14:21])
DevinBooker_FTA = list(shooting_guard['FTA'][21:28])
DonovanMitchell_FTA = list(shooting_guard['FTA'][28:35])
EvanFournier_FTA = list(shooting_guard['FTA'][35:42])
JimmyButler_FTA = list(shooting_guard['FTA'][42:49])
JJRedick_FTA = list(shooting_guard['FTA'][49:56])
LouWilliams_FTA = list(shooting_guard['FTA'][56:63])
VictorOladipo_FTA = list(shooting_guard['FTA'][63:71])

FreeThrowAttempted = np.array([BradleyBeal_FTA, CJMcCollum_FTA, DeMarDeRozan_FTA, DevinBooker_FTA, DonovanMitchell_FTA, EvanFournier_FTA, JimmyButler_FTA, JJRedick_FTA, LouWilliams_FTA, VictorOladipo_FTA])

# %%
FreeThrowAttempted
# Out:
# array([[ 34,  86,  67,  79,  33,  40,  30],
#        [ 27,  38,  46,  45,  26,  51,  17],
#        [ 56,  85, 125, 104,  63, 106,  20],
#        [ 28,  87,  54,  86,  50,  24,   0],
#        [  8,  42,  51,  53,  34,  79,  30],
#        [ 25,  39,  24,  36,  38,  11,   0],
#        [ 21,  74, 116, 118,  64,   0,   0],
#        [  5,  33,  56,  28,  24,  53,  19],
#        [ 22,  65, 104, 115,  62,  94,  29],
#        [ 49,  56,  76,  56,  50,  65,  16]], dtype=int64)

# %% [markdown]
# _____________________________________________________

# %% [markdown]
# ## Vizualization

# %%
#Importing Numpy
import numpy as np
#Importing Matplotlib
import matplotlib.pyplot as plt
#Display Vizualization in the same page
# %matplotlib inline
#Increase the size of the graph
plt.rcParams['figure.figsize'] = 15,7
#Ignoring the Warnings
import warnings
warnings.filterwarnings('ignore')
#To remove the line - <matplotlib.lines.Line2D at 0x1978bdccc88>
plt.show()

# %% [markdown]
# ### Example

# %%
plt.plot(Games[0], c='Black', ls='--', marker='s', ms=7, label=Players[0])
plt.plot(Games[1], c='Red', ls='--', marker='o', ms=7, label=Players[1])
plt.plot(Games[2], c='Green', ls='--', marker='^', ms=7, label=Players[2])
plt.plot(Games[3], c='Blue', ls='--', marker='D', ms=7, label=Players[3])
plt.plot(Games[4], c='Magenta', ls='--', marker='s', ms=7, label=Players[4])
plt.plot(Games[5], c='Black', ls='--', marker='o', ms=7, label=Players[5])
plt.plot(Games[6], c='Red', ls='--', marker='^', ms=7, label=Players[6])
plt.plot(Games[7], c='Green', ls='--', marker='D', ms=7, label=Players[7])
plt.plot(Games[8], c='Blue', ls='--', marker='s', ms=7, label=Players[8])
plt.plot(Games[9], c='Magenta', ls='--', marker='o', ms=7, label=Players[9])
plt.xticks(list(range(0,7)), Month)
plt.legend(loc='upper left', bbox_to_anchor=(1,1))
plt.show()

# %% [markdown]
# ### Tally - Western Conference

# %%
McCollum = []
Booker = []
Mitchell = []
Butler = []
Williams = []

# %% [markdown]
# ### Tally - Eastern Conference

# %%
Beal = []
DeRozan = []
Fournier = []
Redick = []
Oladipo = []

# %% [markdown]
# ## List for Players from from Western and Eastern Conference

# %%
PlayerWC = ["CJMcCollum", "DevinBooker", "DonovanMitchell", "JimmyButler", "LouWilliams"] 
PlayerEC = ["BradleyBeal", "DeMarDeRozan", "EvanFournier", "JJRedick", "VictorOladipo"]

# %% [markdown]
# ### Function for Minutes Played

# %%
def Minutesplot(playerlist=Players):
    Col = {"CJMcCollum":"Black","DevinBooker":"Red","DonovanMitchell":"Green","JimmyButler":"Blue","LouWilliams":"Magenta","BradleyBeal":"Black","DeMarDeRozan":"Red","EvanFournier":"Green","JJRedick":"Blue","VictorOladipo":"Magenta"}
    Mrk = {"CJMcCollum":"s","DevinBooker":"o","DonovanMitchell":"^","JimmyButler":"D","LouWilliams":"s","BradleyBeal":"o","DeMarDeRozan":"^","EvanFournier":"D","JJRedick":"s","VictorOladipo":"o"} 
    for name in playerlist:        
        plt.plot(MinutesPlayed[PlayerD[name]], c=Col[name], ls='--', marker=Mrk[name], ms=7, label=name)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,7)), Month)
    plt.show()

# %% [markdown]
# ### Minutes Played - Western Conference

# %%
Minutesplot(PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. CJ McCollum - 5 points
# #### 2. Donovan Mitchell - 4 points
# #### 3. Lou Williams - 3 points
# #### 4. Jimmy Butler - 2 points
# #### 5. Devin Booker - 1 point

# %%
McCollum.extend([5])
Mitchell.extend([4])
Williams.extend([3])
Butler.extend([2])
Booker.extend([1])

# %% [markdown]
# ### Minutes Played - Eastern Conference

# %%
Minutesplot(PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Bradley Beal - 5 points
# #### 2. DemarDeRozan - 4 points
# #### 3. Victor Oladipo - 3 points
# #### 4. JJ Redick - 2 points
# #### 5. Evan Fournier - 1 point

# %%
Beal.extend([5])
DeRozan.extend([4])
Oladipo.extend([3])
Redick.extend([2])
Fournier.extend([1])

# %% [markdown]
# _____________________________________________

# %% [markdown]
# ### Function for Points Scored

# %%
def Pointsplot(playerlist=Players):
    Col = {"CJMcCollum":"Black","DevinBooker":"Red","DonovanMitchell":"Green","JimmyButler":"Blue","LouWilliams":"Magenta","BradleyBeal":"Black","DeMarDeRozan":"Red","EvanFournier":"Green","JJRedick":"Blue","VictorOladipo":"Magenta"}
    Mrk = {"CJMcCollum":"s","DevinBooker":"o","DonovanMitchell":"^","JimmyButler":"D","LouWilliams":"s","BradleyBeal":"o","DeMarDeRozan":"^","EvanFournier":"D","JJRedick":"s","VictorOladipo":"o"} 
    for name in playerlist:        
        plt.plot(MinutesPlayed[PlayerD[name]], c=Col[name], ls='--', marker=Mrk[name], ms=7, label=name)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,7)), Month)
    plt.show()

# %% [markdown]
# ### Points Scored - Western Conference

# %%
Pointsplot(PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Lou Williams - 5 points
# #### 2. CJ McCollum - 4 points
# #### 3. Donovan Mitchell - 3 points
# #### 4. Devin Booker - 2 points
# #### 5. Jimmy Butler - 1 point

# %%
Williams.extend([5])
McCollum.extend([4])
Mitchell.extend([3])
Booker.extend([2])
Butler.extend([1])

# %% [markdown]
# ### Points Scored - Eastern Conference

# %%
Pointsplot(PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Bradley Beal - 5 points
# #### 2. DeMar DeRozan - 4 points
# #### 3. Victor Oladipo - 3 points
# #### 4. JJ Redick - 2 points
# #### 5. Evan Fournier - 1 point

# %%
Beal.extend([5])
DeRozan.extend([4])
Oladipo.extend([3])
Redick.extend([2])
Fournier.extend([1])

# %% [markdown]
# ____________________________________________

# %% [markdown]
# ### Function for Field Goals Made

# %%
def FieldGoalsplot(playerlist=Players):
    Col = {"CJMcCollum":"Black","DevinBooker":"Red","DonovanMitchell":"Green","JimmyButler":"Blue","LouWilliams":"Magenta","BradleyBeal":"Black","DeMarDeRozan":"Red","EvanFournier":"Green","JJRedick":"Blue","VictorOladipo":"Magenta"}
    Mrk = {"CJMcCollum":"s","DevinBooker":"o","DonovanMitchell":"^","JimmyButler":"D","LouWilliams":"s","BradleyBeal":"o","DeMarDeRozan":"^","EvanFournier":"D","JJRedick":"s","VictorOladipo":"o"} 
    for name in playerlist:        
        plt.plot(MinutesPlayed[PlayerD[name]], c=Col[name], ls='--', marker=Mrk[name], ms=7, label=name)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,7)), Month)
    plt.show()

# %% [markdown]
# ### Field Goals - Western Conference

# %%
FieldGoalsplot(PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. CJ McCollum -  5 points
# #### 2 .Donovan Mitchell - 4 points
# #### 3. Lou Williams - 3 points
# #### 4. Devin Booker - 2 points
# #### 5. Jimmy Butler - 1 point

# %%
McCollum.extend([5])
Mitchell.extend([4])
Williams.extend([3])
Booker.extend([2])
Butler.extend([1])

# %% [markdown]
# ### Field Goals - Eastern Conference

# %%
FieldGoalsplot(PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Bradley Beal -  5 points
# #### 2. DeMar DeRozan - 4 points
# #### 3. Victor Oladipo - 3 points
# #### 4. JJ Redick - 2 points
# #### 5. Evan Fournier - 1 point

# %%
Beal.extend([5])
DeRozan.extend([4])
Oladipo.extend([3])
Redick.extend([2])
Fournier.extend([1])

# %% [markdown]
# _______________________________________

# %% [markdown]
# ### Function for Rebounds

# %%
def Reboundsplot(playerlist=Players):
    Col = {"CJMcCollum":"Black","DevinBooker":"Red","DonovanMitchell":"Green","JimmyButler":"Blue","LouWilliams":"Magenta","BradleyBeal":"Black","DeMarDeRozan":"Red","EvanFournier":"Green","JJRedick":"Blue","VictorOladipo":"Magenta"}
    Mrk = {"CJMcCollum":"s","DevinBooker":"o","DonovanMitchell":"^","JimmyButler":"D","LouWilliams":"s","BradleyBeal":"o","DeMarDeRozan":"^","EvanFournier":"D","JJRedick":"s","VictorOladipo":"o"} 
    for name in playerlist:        
        plt.plot(Rebounds[PlayerD[name]], c=Col[name], ls='--', marker=Mrk[name], ms=7, label=name)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,7)), Month)
    plt.show()

# %% [markdown]
# ### Rebounds - Western Conference

# %%
Reboundsplot(PlayerWC)

# %% [markdown]
# ### Rankings
# #### 1. CJ McCollum - 5 points
# #### 2. Jimmy Butler - 4 points
# #### 3. Donovan Mitchell - 3 points
# #### 4. Devin Booker - 2 points
# #### 5 .Lou Williams - 1 point

# %%
McCollum.extend([5])
Butler.extend([4])
Mitchell.extend([3])
Booker.extend([2])
Williams.extend([1])

# %% [markdown]
# ### Rebounds - Eastern Conference

# %%
Reboundsplot(PlayerEC)

# %% [markdown]
# ### Rankings
# #### 1. Victor Oladipo - 5 points
# #### 2. Bradley Beal - 4 points
# #### 3. DeMar DeRozan - 3 points
# #### 4. JJ Redick - 2 points
# #### 5. Evan Fournier - 1 point

# %%
Oladipo.extend([5])
Beal.extend([4])
DeRozan.extend([3])
Redick.extend([2])
Fournier.extend([1])

# %% [markdown]
# __________________________________________________________

# %% [markdown]
# ### Function for Assists

# %%
def Assistsplot(playerlist=Players):
    Col = {"CJMcCollum":"Black","DevinBooker":"Red","DonovanMitchell":"Green","JimmyButler":"Blue","LouWilliams":"Magenta","BradleyBeal":"Black","DeMarDeRozan":"Red","EvanFournier":"Green","JJRedick":"Blue","VictorOladipo":"Magenta"}
    Mrk = {"CJMcCollum":"s","DevinBooker":"o","DonovanMitchell":"^","JimmyButler":"D","LouWilliams":"s","BradleyBeal":"o","DeMarDeRozan":"^","EvanFournier":"D","JJRedick":"s","VictorOladipo":"o"} 
    for name in playerlist:        
        plt.plot(Assists[PlayerD[name]], c=Col[name], ls='--', marker=Mrk[name], ms=7, label=name)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,7)), Month)
    plt.show()

# %% [markdown]
# ### Assist - Western Conference

# %%
Assistsplot(PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Lou Williams - 5 points
# #### 2. Donovan Mitchell - 4 points
# #### 3. Jimmy Butler - 3 points
# #### 4. CJ McCollum - 2 points
# #### 5. Devin Booker - 1 point

# %%
Williams.extend([5])
Mitchell.extend([4])
Butler.extend([3])
McCollum.extend([2])
Booker.extend([1])

# %% [markdown]
# ### Assist - Eastern Conference

# %%
Reboundsplot(PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. DeMar DeRozan - 5 points
# #### 2. Bradley Beal - 4 points
# #### 3. Victor Oladipo - 3 points
# #### 4. JJ Redick - 2 points
# #### 5. Evan Fournier - 1 point

# %%
DeRozan.extend([5])
Beal.extend([4])
Oladipo.extend([3])
Redick.extend([2])
Fournier.extend([1])

# %% [markdown]
# __________________________________________

# %% [markdown]
# ### Function for Manual Calculation

# %%
def Calculation(data, playerlist=Players):
    Col = {"CJMcCollum":"Black","DevinBooker":"Red","DonovanMitchell":"Green","JimmyButler":"Blue","LouWilliams":"Magenta","BradleyBeal":"Black","DeMarDeRozan":"Red","EvanFournier":"Green","JJRedick":"Blue","VictorOladipo":"Magenta"}
    Mrk = {"CJMcCollum":"s","DevinBooker":"o","DonovanMitchell":"^","JimmyButler":"D","LouWilliams":"s","BradleyBeal":"o","DeMarDeRozan":"^","EvanFournier":"D","JJRedick":"s","VictorOladipo":"o"} 
    for name in playerlist:        
        plt.plot(data[PlayerD[name]], c=Col[name], ls='--', marker=Mrk[name], ms=7, label=name)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,7)), Month)
    plt.show()

# %% [markdown]
# ### Shooting Accuracy - Western Conference

# %%
Calculation(FieldGoals/FieldGoalsAttempted, PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. CJ McCollum - 5 points
# #### 2. Jimmy Butler - 4 points
# #### 3. Donovan Mitchell - 3 points
# #### 4. Lou Williams - 2 points
# #### 5. Devin Booker - 1 point

# %%
McCollum.extend([5])
Butler.extend([4])
Mitchell.extend([3])
Williams.extend([2])
Booker.extend([1])

# %% [markdown]
# ### Shooting Accuracy - Eastern Conference

# %%
Calculation(FieldGoals/FieldGoalsAttempted, PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Victor Oladipo - 5 points
# #### 2. DeMar DeRozan - 4 points
# #### 3. Evan Fournier - 3 points
# #### 4. JJ Redick - 2 points
# #### 5. Bradley Beal - 1 point

# %%
Oladipo.extend([5])
DeRozan.extend([4])
Fournier.extend([3])
Redick.extend([2])
Beal.extend([1])

# %% [markdown]
# _______________________________________________________

# %% [markdown]
# ### Points/Minutes- Western Conference

# %%
Calculation(PointsMade/MinutesPlayed, PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Devin Booker - 5 points
# #### 2. Lou Williams - 4 points
# #### 3. Donovan Mitchell - 3 points
# #### 4. CJ McCollum - 2 points
# #### 5. Jimmy Butler - 1 point

# %%
Booker.extend([5])
Williams.extend([4])
Mitchell.extend([3])
McCollum.extend([2])
Butler.extend([1])

# %% [markdown]
# ### Points/Minutes - Western Conference

# %%
Calculation(PointsMade/MinutesPlayed, PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. Victor Oladipo - 5 points
# #### 2. DeMar DeRozan - 4 points
# #### 3. Bradley Beal - 3 points
# #### 4. JJ Redick - 2 points
# #### 5. Evan Fournier - 1 point

# %%
Oladipo.extend([5])
DeRozan.extend([4])
Beal.extend([3])
Redick.extend([2])
Fournier.extend([1])

# %% [markdown]
# _____________________________________________________

# %% [markdown]
# ### Free Throw Accuracy - Western Conference

# %%
Calculation(FreeThrowMade/FreeThrowAttempted, PlayerWC)

# %% [markdown]
# ### Ranking
# #### 1. Lou Williams - 5 points
# #### 2. Devin Booker - 4 points
# #### 3. CJ McCollum - 3 points
# #### 4. Donovan Mitchell - 2 points
# #### 5. Jimmy Butler - 1 point

# %%
Williams.extend([5])
Booker.extend([4])
McCollum.extend([3])
Mitchell.extend([2])
Butler.extend([1])

# %% [markdown]
# ### Free Throw Accuracy - Eastern Conference

# %%
Calculation(FreeThrowMade/FreeThrowAttempted, PlayerEC)

# %% [markdown]
# ### Ranking
# #### 1. JJ Redick - 5 points
# #### 2. Evan Fournier - 4 points
# #### 3. DeMar DeRozan - 3 points
# #### 4. Bradley Beal - 2 points
# #### 5. Victor Oladipo - 1 point

# %%
Redick.extend([5])
Fournier.extend([4])
DeRozan.extend([3])
Beal.extend([2])
Oladipo.extend([1])

# %% [markdown]
# ___________________________________________________

# %% [markdown]
# _______________________________________

# %% [markdown]
# ## Final Rankings - Western Conference

# %%
#Tallying up the points
McCollum_tally = sum(McCollum)
Booker_tally = sum(Booker)
Mitchell_tally = sum(Mitchell)
Butler_tally = sum(Butler)
Williams_tally = sum(Williams)

#X-Axis (Labels)
players_label = ['CJ McCollum', 'Devin Booker', 'Donovan Mitchell', 'Jimmy Butler', 'Lou Williams']
#Converting the X-Axis into an array
players_label_arr = np.array(players_label)

#Y-Axis (Values for the labels)
tally = [McCollum_tally, Booker_tally, Mitchell_tally, Butler_tally, Williams_tally]

#Plotting the Bar
plt.bar(players_label_arr, tally)

#Labelling X and Y axes
plt.xlabel('Player Names', fontsize = 20, color='DarkBlue')
plt.ylabel('Total Points', fontsize = 20, color='DarkBlue')

#The Title
plt.title("WC Shooting Guard - Final Rankings", fontsize=35, color="DarkBlue", fontname="Console")

#Displaying the Bar
plt.show()

# %% [markdown]
# ### 1. CJ McCollum
# ### 2. Lou Williams
# ### 3. Donovan Mitchell
# ### 4. Devin Booker
# ### 5. Jimmy Butler

# %% [markdown]
# ## First Choice Shooting Guard (Western Conference): CJ McCollum

# %% [markdown]
# ![CJ McCollum](https://arc-anglerfish-arc2-prod-guernseypress-mna.s3.amazonaws.com/public/QNYPQLJTCRAGPFWK64HIZZU2PM.jpg)

# %% [markdown]
# ## Reserve Shooting Guard (Western Conference): Lou Williams

# %% [markdown]
# ![Lou Williams](https://static.ethika.com/wp-content/uploads/2017/12/la-sp-clippers-wizards-20171209-pictures-002-1.jpg)

# %% [markdown]
# ___________________________________________________

# %% [markdown]
# ### Final Rankings - Eastern Conference

# %%
#Tallying up the points
Beal_tally = sum(Beal)
DeRozan_tally = sum(DeRozan)
Fournier_tally = sum(Fournier)
Redick_tally = sum(Redick)
Oladipo_tally = sum(Oladipo)

#X-Axis (Labels)
players_label = ['Bradley Beal', 'DeMar DeRozan', 'Evan Fournier', 'JJ Redick', 'Victor Oladipo']
#Converting the X-Axis into an array
players_label_arr = np.array(players_label)

#Y-Axis (Values for the labels)
tally = [Beal_tally, DeRozan_tally, Fournier_tally, Redick_tally, Oladipo_tally]

#Plotting the Bar
plt.bar(players_label_arr, tally)

#Labelling X and Y axes
plt.xlabel('Player Names', fontsize = 20, color='DarkBlue')
plt.ylabel('Total Points', fontsize = 20, color='DarkBlue')

#The Title
plt.title("EC Shooting Guard - Final Rankings", fontsize=35, color="DarkBlue", fontname="Console")

#Displaying the Bar
plt.show()

# %% [markdown]
# ### 1. DeMar DeRozan
# ### 2. Bradley Beal
# ### 3. Victor Oladipo
# ### 4. JJ Redick
# ### 5. Evan Fournier

# %% [markdown]
# ## First Choice Shooting Guard (Eastern Conference): DeMar DeRozan

# %% [markdown]
# ![DeMar DeRozan](https://thesportspost.com/wp-content/uploads/2017/07/why-demar-derozan-is-the-38th-best-player-in-the-nba-800x600.jpg)

# %% [markdown]
# ## Reserve Shooting Guard (Eastern Conference): Bradley Beal

# %% [markdown]
# ![Bradley Beal](https://thesportspost.com/wp-content/uploads/2017/08/why-bradley-beal-is-the-30th-best-player-in-the-nba-800x600.jpg)
